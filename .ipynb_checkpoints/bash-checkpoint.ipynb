# %% [markdown]
# ---
# ---
# ---
#
# # bash.ipynb
#
# ---
# ---

# %% [markdown]
# ## help() FOR SHELL COMMANDS written in python

# %%
strings = ["jupyter","npm","uv","pipenv"]
line = "--------------------------------------------------------------------------------"

def helper(name:str = ""):
    # !echo ""
    # !echo "--------------------------------------------------------------------------------"
    # !echo "--------------------------------------------------------------------------------"
    # !tldr $name
    # !echo "--------------------------------------------------------------------------------"
    # !$name --help
    # !echo "--------------------------------------------------------------------------------"
    # !man $name
    # !echo "--------------------------------------------------------------------------------"
    # !echo "--------------------------------------------------------------------------------"
    # !echo ""
    
def helpme():
    #print(strings.length)
    for string in strings:
        helper(string)

helpme()
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# jupyter
#
# Web application to create and share documents that contain code, visualizations and notes.
# Primarily used for data analysis, scientific computing and machine learning.
# More information: https://docs.jupyter.org/en/latest/.
#
#  - Start a Jupyter notebook server in the current directory:
#    jupyter notebook
#
#  - Open a specific Jupyter notebook:
#    jupyter notebook example.ipynb
#
#  - Export a specific Jupyter notebook into another format:
#    jupyter nbconvert --to html|markdown|pdf|script example.ipynb
#
#  - Start a server on a specific port:
#    jupyter notebook --port port
#
#  - List currently running notebook servers:
#    jupyter notebook list
#
#  - Stop the currently running server:
#    jupyter notebook stop
#
#  - Start JupyterLab, if installed, in the current directory:
#    jupyter lab
# --------------------------------------------------------------------------------
# /bin/bash: line 1: jupyter: command not found
# --------------------------------------------------------------------------------
# No manual entry for jupyter
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# npm
#
# JavaScript and Node.js package manager.
# Manage Node.js projects and their module dependencies.
# More information: https://docs.npmjs.com/cli/npm.
#
#  - Create a package.json file with default values (omit --yes to do it interactively):
#    npm init [-y|--yes]
#
#  - Download all the packages listed as dependencies in package.json:
#    npm [i|install]
#
#  - Download a specific version of a package and add it to the list of dependencies in package.json:
#    npm [i|install] package_name@version
#
#  - Download the latest version of a package and add it to the list of dev dependencies in package.json:
#    npm [i|install] package_name [-D|--save-dev]
#
#  - Download the latest version of a package and install it globally:
#    npm [i|install] [-g|--global] package_name
#
#  - Uninstall a package and remove it from the list of dependencies in package.json:
#    npm [r|uninstall] package_name
#
#  - List all locally installed dependencies:
#    npm [ls|list]
#
#  - List all top-level globally installed packages:
#    npm [ls|list] [-g|--global] --depth 0
# --------------------------------------------------------------------------------
# npm <command>
#
# Usage:
#
# npm install        install all the dependencies in your project
# npm install <foo>  add the <foo> dependency to your project
# npm test           run this project's tests
# npm run <foo>      run the script named <foo>
# npm <command> -h   quick help on <command>
# npm -l             display usage info for all commands
# npm help <term>    search for help on <term>
# npm help npm       more involved overview
#
# All commands:
#
#     access, adduser, audit, bugs, cache, ci, completion,
#     config, dedupe, deprecate, diff, dist-tag, docs, doctor,
#     edit, exec, explain, explore, find-dupes, fund, get, help,
#     hook, init, install, install-ci-test, install-test, link,
#     ll, login, logout, ls, org, outdated, owner, pack, ping,
#     pkg, prefix, profile, prune, publish, query, rebuild, repo,
#     restart, root, run-script, search, set, shrinkwrap, star,
#     stars, start, stop, team, test, token, uninstall, unpublish,
#     unstar, update, version, view, whoami
#
# Specify configs in the ini-formatted file:
#     /home/me/.npmrc
# or on the command line via: npm <command> --key=value
#
# More configuration info: npm help config
# Configuration fields: npm help 7 config
#
# npm@9.2.0 /usr/share/nodejs/npm
# --------------------------------------------------------------------------------
# NPM(1)                      General Commands Manual                     NPM(1)
#
# NAME
#        npm
#
# Synopsis
#        <!-- AUTOGENERATED USAGE DESCRIPTIONS -->
#
# Version
#        @VERSION@
#
# Description
#        npm is the package manager for the Node JavaScript platform.  It puts
#        modules in place so that node can find them, and manages dependency
#        conflicts intelligently.
#
#        It is extremely configurable to support a variety of use cases.  Most
#        commonly, you use it to publish, discover, install, and develop node
#        programs.
#
#        Run npm help to get a list of available commands.
#
# Important
#        npm comes preconfigured to use npm's public registry at
#        https://registry.npmjs.orgby default. Use of the npm public registry is
#        subject to terms of use available at
#        https://docs.npmjs.com/policies/terms
#
#        You can configure npm to use any compatible registry you like, and even
#        run your own registry. Use of someone else's registry is governed by
#        their terms of use.
#
# Introduction
#        You probably got npm because you want to install stuff.
#
#        The very first thing you will most likely want to run in any node
#        program is npm install to install its dependencies.
#
#        You can also run npm install blerg to install the latest version of
#        "blerg".  Check out npm install for more
#        info.  It can do a lot of stuff.
#
#        Use the npm search command to show everything that's available in the
#        public registry.  Use npm ls to show everything you've installed.
#
# Dependencies
#        If a package lists a dependency using a git URL, npm will install that
#        dependency using the git
#        command and will generate an error if it is not installed.
#
#        If one of the packages npm tries to install is a native node module and
#        requires compiling of C++ Code, npm will use
#        node-gyp for that task.
#        For a Unix system, node-gyp
#        needs Python, make and a buildchain like GCC. On Windows,
#        Python and Microsoft Visual Studio C++ are needed. For more information
#        visit the node-gyp repository and
#        the node-gyp Wiki.
#
# Directories
#        See folders to learn about where npm puts
#        stuff.
#
#        In particular, npm has two modes of operation:
#
#         • local mode:
#           npm installs packages into the current project directory, which
#           defaults to the current working directory.  Packages install to
#           ./node_modules, and bins to ./node_modules/.bin.
#
#         • global mode:
#           npm installs packages into the install prefix at
#           $npm_config_prefix/lib/node_modules and bins to
#           $npm_config_prefix/bin.
#
#        Local mode is the default.  Use -g or --global on any command to
#        run in global mode instead.
#
# Developer Usage
#        If you're using npm to develop and publish your code, check out the
#        following help topics:
#
#         • json:
#           Make a package.json file.  See
#           package.json.
#
#         • link:
#           Links your current working code into Node's path, so that you don't
#           have  to reinstall every time you make a change.  Use npm link to do
#           this.
#
#         • install:
#           It's a good idea to install things if you don't need the symbolic
#           link.  Especially, installing other peoples code from  the  registry
#           is
#           done via npm install
#
#         • adduser:
#           Create an account or log in.  When you do this, npm will store
#           credentials in the user config file.
#
#         • publish:
#           Use the npm publish command to upload your
#           code to the registry.
#
#    Configuration
#        npm is extremely configurable.  It reads its configuration options from
#        5 places.
#
#         • Command line switches:
#           Set a config with --key val.  All keys take a value, even if they
#           are booleans (the config parser doesn't know what the options are at
#           the time of parsing).  If you do not provide a value (--key) then
#           the option is set to boolean true.
#
#         • Environment Variables:
#           Set any config by prefixing the name in an environment variable with
#           npm_config_.  For example, export npm_config_key=val.
#
#         • User Configs:
#           The file at $HOME/.npmrc is an ini-formatted list of configs.  If
#           present, it is parsed.  If the userconfig option is set in the cli
#           or env, that file will be used instead.
#
#         • Global Configs:
#           The file found at ./etc/npmrc (relative to the global prefix will be
#           parsed if it is found.  See npm prefix for
#           more info on the global prefix.  If the globalconfig option is set
#           in the cli, env, or user config, then that file is parsed instead.
#
#         • Defaults:
#           npm's default configuration options are defined in
#           lib/utils/config-defs.js.  These must not be changed.
#
#        See config for much much more information.
#
# Contributions
#        Patches welcome!
#
#        If you would like to help, but don't know what to work on, read the
#        contributing
#        guidelines and
#        check the issues list.
#
# Bugs
#        When you find issues, please report them:
#        https://github.com/npm/cli/issues
#
#        Please be sure to follow the template and bug reporting guidelines.
#
# Feature Requests
#        Discuss new feature ideas on our discussion forum:
#
#         • https://github.com/npm/feedback
#
#        Or suggest formal RFC proposals:
#
#         • https://github.com/npm/rfcs
#
# See Also
#         • npm help
#
#         • package.json
#
#         • npmrc
#
#         • npm config
#
#         • npm install
#
#         • npm prefix
#
#         • npm publish
#
# 9.2.0                            December 2022                          NPM(1)
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# uv
#
# A fast Python package and project manager.
# Some subcommands such as tool and python have their own usage documentation.
# More information: https://docs.astral.sh/uv/reference/cli.
#
#  - Create a new Python project in the current directory:
#    uv init
#
#  - Create a new Python project at the specified path:
#    uv init path/to/directory
#
#  - Add a new dependency to the project:
#    uv add package
#
#  - Remove a dependency from the project:
#    uv remove package
#
#  - Run a script in the project's environment:
#    uv run path/to/script.py
#
#  - Run a command in the project's environment:
#    uv run command
#
#  - Update a project's environment from pyproject.toml:
#    uv sync
#
#  - Create a lock file for the project's dependencies:
#    uv lock
# --------------------------------------------------------------------------------
# An extremely fast Python package manager.
#
# Usage: uv [OPTIONS] <COMMAND>
#
# Commands:
#   auth     Manage authentication
#   run      Run a command or script
#   init     Create a new project
#   add      Add dependencies to the project
#   remove   Remove dependencies from the project
#   version  Read or update the project's version
#   sync     Update the project's environment
#   lock     Update the project's lockfile
#   export   Export the project's lockfile to an alternate format
#   tree     Display the project's dependency tree
#   format   Format Python code in the project
#   tool     Run and install commands provided by Python packages
#   python   Manage Python versions and installations
#   pip      Manage Python packages with a pip-compatible interface
#   venv     Create a virtual environment
#   build    Build Python packages into source distributions and wheels
#   publish  Upload distributions to an index
#   cache    Manage uv's cache
#   self     Manage the uv executable
#   help     Display documentation for a command
#
# Cache options:
#   -n, --no-cache               Avoid reading from or writing to the cache,
#                                instead using a temporary directory for the
#                                duration of the operation [env: UV_NO_CACHE=]
#       --cache-dir <CACHE_DIR>  Path to the cache directory [env: UV_CACHE_DIR=]
#
# Python options:
#       --managed-python       Require use of uv-managed Python versions [env:
#                              UV_MANAGED_PYTHON=]
#       --no-managed-python    Disable use of uv-managed Python versions [env:
#                              UV_NO_MANAGED_PYTHON=]
#       --no-python-downloads  Disable automatic downloads of Python. [env:
#                              "UV_PYTHON_DOWNLOADS=never"]
#
# Global options:
#   -q, --quiet...
#           Use quiet output
#   -v, --verbose...
#           Use verbose output
#       --color <COLOR_CHOICE>
#           Control the use of color in output [possible values: auto, always,
#           never]
#       --native-tls
#           Whether to load TLS certificates from the platform's native
#           certificate store [env: UV_NATIVE_TLS=]
#       --offline
#           Disable network access [env: UV_OFFLINE=]
#       --allow-insecure-host <ALLOW_INSECURE_HOST>
#           Allow insecure connections to a host [env: UV_INSECURE_HOST=]
#       --no-progress
#           Hide all progress outputs [env: UV_NO_PROGRESS=]
#       --directory <DIRECTORY>
#           Change to the given directory prior to running the command
#       --project <PROJECT>
#           Run the command within the given project directory [env: UV_PROJECT=]
#       --config-file <CONFIG_FILE>
#           The path to a `uv.toml` file to use for configuration [env:
#           UV_CONFIG_FILE=]
#       --no-config
#           Avoid discovering configuration files (`pyproject.toml`, `uv.toml`)
#           [env: UV_NO_CONFIG=]
#   -h, --help
#           Display the concise help for this command
#   -V, --version
#           Display the uv version
#
# Use `uv help` for more details.
# --------------------------------------------------------------------------------
# No manual entry for uv
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# pipenv
#
# Simple and unified Python development workflow.
# Manage packages and the virtual environment for a project.
# More information: https://pypi.org/project/pipenv.
#
#  - Create a new project:
#    pipenv
#
#  - Create a new project using Python 3:
#    pipenv --three
#
#  - Install a package:
#    pipenv install package
#
#  - Install all the dependencies for a project:
#    pipenv install
#
#  - Install all the dependencies for a project (including dev packages):
#    pipenv install --dev
#
#  - Uninstall a package:
#    pipenv uninstall package
#
#  - Start a shell within the created virtual environment:
#    pipenv shell
#
#  - Generate a requirements.txt (list of dependencies) for a project:
#    pipenv lock --requirements
# --------------------------------------------------------------------------------
# Usage: pipenv [OPTIONS] COMMAND [ARGS]...
#
# Options:
#   --where                         Output project home information.
#   --venv                          Output virtualenv information.
#   --py                            Output Python interpreter information.
#   --envs                          Output Environment Variable options.
#   --rm                            Remove the virtualenv.
#   --bare                          Minimal output.
#   --man                           Display manpage.
#   --support                       Output diagnostic information for use in
#                                   GitHub issues.
#   --site-packages / --no-site-packages
#                                   Enable site-packages for the virtualenv.
#                                   [env var: PIPENV_SITE_PACKAGES]
#   --python TEXT                   Specify which version of Python virtualenv
#                                   should use.
#   --three                         Use Python 3 when creating virtualenv.
#                                   Deprecated
#   --clear                         Clears caches (pipenv, pip).  [env var:
#                                   PIPENV_CLEAR]
#   -q, --quiet                     Quiet mode.
#   -v, --verbose                   Verbose mode.
#   --pypi-mirror TEXT              Specify a PyPI mirror.
#   --version                       Show the version and exit.
#   -h, --help                      Show this message and exit.
#
#
# Usage Examples:
#    Create a new project using Python 3.7, specifically:
#    $ pipenv --python 3.7
#
#    Remove project virtualenv (inferred from current directory):
#    $ pipenv --rm
#
#    Install all dependencies for a project (including dev):
#    $ pipenv install --dev
#
#    Create a lockfile containing pre-releases:
#    $ pipenv lock --pre
#
#    Show a graph of your installed dependencies:
#    $ pipenv graph
#
#    Check your installed dependencies for security vulnerabilities:
#    $ pipenv check
#
#    Install a local setup.py into your virtual environment/Pipfile:
#    $ pipenv install -e .
#
#    Use a lower-level pip command:
#    $ pipenv run pip freeze
#
# Commands:
#   check         Checks for PyUp Safety security vulnerabilities and against
#                 PEP 508 markers provided in Pipfile.
#   clean         Uninstalls all packages not specified in Pipfile.lock.
#   graph         Displays currently-installed dependency graph information.
#   install       Installs provided packages and adds them to Pipfile, or (if no
#                 packages are given), installs all packages from Pipfile.
#   lock          Generates Pipfile.lock.
#   open          View a given module in your editor.
#   requirements  Generate a requirements.txt from Pipfile.lock.
#   run           Spawns a command installed into the virtualenv.
#   scripts       Lists scripts in current environment config.
#   shell         Spawns a shell within the virtualenv.
#   sync          Installs all packages specified in Pipfile.lock.
#   uninstall     Uninstalls a provided package and removes it from Pipfile.
#   update        Runs lock, then sync.
#   verify        Verify the hash in Pipfile.lock is up-to-date.
# --------------------------------------------------------------------------------
# PIPENV(1)                           pipenv                           PIPENV(1)
#
# Pipenv uses a set of commands to manage your Project's dependencies and custom
# scripts.  It replaces the use of Makefile, direct calls to pip and  python  -m
# venv  or  virtualenv.   to create virtual environments and install packages in
# them.  Pipenv uses two files to do this: Pipfile  and Pipfile.lock (which will
# look familiar if you are used to packages manager like yarn or npm).
#
# The main commands are:
#
#        • install -
#
#          Will  create  a  virtual env and install dependencies (if it does not
#          exist already) The dependencies will be installed inside.
#
#        • install package==0.2 -
#
#          Will add the package in version 0.2 to the virtual environment and to
#          Pipfile and Pipfile.lock
#
#        • uninstall - Will remove the dependency
#
#        • lock  -  Regenerate  Pipfile.lock and updates the dependencies inside
#          it.
#
#        These are intended to replace $ pip install usage, as  well  as  manual
#        virtualenv management.
#
#        • graph  will  show  you a dependency graph of your installed dependen‐
#          cies.
#
#        • shell will spawn a shell with the virtualenv  activated.  This  shell
#          can be deactivated by using exit.
#
#        • run  will run a given command from the virtualenv, with any arguments
#          forwarded (e.g. $ pipenv run python or $ pipenv run pip freeze).
#
#        • check checks for security vulnerabilities and asserts  that  PEP  508
#          requirements are being met by the current environment.
#
# AUTHOR
#        Python Packaging Authority
#
# COPYRIGHT
#        2020.  A  project  founded  by  Kenneth  Reitz  and  maintained  by  <a
#        href="https://www.pypa.io/en/latest/">Python    Packaging     Authority
#        (PyPA).</a>
#
# 2022.12.19                       Dec 19, 2022                        PIPENV(1)
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------

# %% [markdown]
# ---
# aa-enabled
# aarch64-linux-gnu-nm
# ant
# aa-exec
# aarch64-linux-gnu-objcopy
# aplay
# aa-features-abi
# aarch64-linux-gnu-objdump
# aplaymidi
# aarch64-linux-gnu-addr2line
# aarch64-linux-gnu-pkgconf
# apparmor_parser
# aarch64-linux-gnu-ar
# aarch64-linux-gnu-pkg-config
# apparmor_status
# aarch64-linux-gnu-as
# aarch64-linux-gnu-python3.11-config
# applygnupgdefaults
# aarch64-linux-gnu-c++filt
# aarch64-linux-gnu-python3-config
# appres
# aarch64-linux-gnu-cpp
# aarch64-linux-gnu-ranlib
# apropos
# aarch64-linux-gnu-cpp-12
# aarch64-linux-gnu-readelf
# apt
# aarch64-linux-gnu-dwp
# aarch64-linux-gnu-size
# apt-cache
# aarch64-linux-gnu-elfedit
# aarch64-linux-gnu-strings
# apt-cdrom
# aarch64-linux-gnu-g++
# aarch64-linux-gnu-strip
# apt-config
# aarch64-linux-gnu-g++-12
# aa-remove-unknown
# apt-extracttemplates
# aarch64-linux-gnu-gcc
# aa-status
# apt-ftparchive
# aarch64-linux-gnu-gcc-12
# aa-teardown
# apt-get
# aarch64-linux-gnu-gcc-ar
# accessdb
# apt-key
# aarch64-linux-gnu-gcc-ar-12
# aconnect
# apt-listchanges
# aarch64-linux-gnu-gcc-nm
# acorn
# apt-mark
# aarch64-linux-gnu-gcc-nm-12
# acyclic
# apt-sortpkgs
# aarch64-linux-gnu-gcc-ranlib
# addgnupghome
# ar
# aarch64-linux-gnu-gcc-ranlib-12
# addgroup
# arborist
# aarch64-linux-gnu-gcov
# addpart
# arch
# aarch64-linux-gnu-gcov-12
# addr2line
# arecord
# aarch64-linux-gnu-gcov-dump
# add-shell
# arecordmidi
# aarch64-linux-gnu-gcov-dump-12
# adduser
# arp
# aarch64-linux-gnu-gcov-tool
# agetty
# arpd
# aarch64-linux-gnu-gcov-tool-12
# agnostics
# arptables
# aarch64-linux-gnu-gold
# airscan-discover
# arptables-nft
# aarch64-linux-gnu-gp-archive
# alacarte
# arptables-nft-restore
# aarch64-linux-gnu-gp-collect-app
# alias
# arptables-nft-save
# aarch64-linux-gnu-gp-display-html
# alsabat
# arptables-restore
# aarch64-linux-gnu-gp-display-src
# alsabat-test
# arptables-save
# aarch64-linux-gnu-gp-display-text
# alsactl
# as
# aarch64-linux-gnu-gprof
# alsa-info
# aseqdump
# aarch64-linux-gnu-gprofng
# alsaloop
# aseqnet
# aarch64-linux-gnu-ld
# alsamixer
# aspell-autobuildhash
# aarch64-linux-gnu-ld.bfd
# alsatplg
# autotouch
# aarch64-linux-gnu-ld.gold
# alsaucm
# avahi-daemon
# aarch64-linux-gnu-lto-dump
# amidi
# awk
# aarch64-linux-gnu-lto-dump-12
# amixer
# axfer
#
# b2sum                       bash                        bluemoon                    busctl
# babeljs                     bashbug                     bluetoothctl                busybox
# babeljs-7                   bc                          bluetoothd                  bwrap
# babeljs-7-external-helpers  bcomps                      brasero                     bzcat
# babeljs-7-node              bdftopcf                    break                       bzcmp
# babeljs-7-parser            bdftruncate                 bridge                      bzdiff
# babeljs-external-helpers    bg                          browserslist                bzegrep
# babeljs-node                bind                        btattach                    bzexe
# babeljs-parser              blkdeactivate               bthelper                    bzfgrep
# badblocks                   blkdiscard                  btmgmt                      bzgrep
# base32                      blkid                       btmon                       bzip2
# base64                      blkmapd                     btuart                      bzip2recover
# basename                    blkzone                     builtin                     bzless
# basenc                      blockdev                    bunzip2                     bzmore
#
# c++                         cd-iccdump                  cifscreds                   cpan
# c89                         cd-it8                      cifs.idmap                  cpan5.36-aarch64-linux-gnu
# c89-gcc                     cdrdao                      cifs.upcall                 cpgr
# c99                         cdrecord                    ciptool                     cpio
# c99-gcc                     cec-compliance              circo                       cpp
# cache_check                 cec-ctl                     cjpeg                       cpp-12
# cache_dump                  cec-follower                ckbcomp                     cppw
# cache_metadata_size         certtool                    cksum                       cracklib-check
# cache_repair                cfdisk                      clear                       cracklib-format
# cache_restore               c++filt                     clear_console               cracklib-packer
# cache_writeback             cgdisk                      cluster                     cracklib-unpacker
# calibre                     chacl                       cmatrix                     create-cracklib-dict
# calibre-complete            chage                       cmp                         create_xauth
# calibre-customize           chardet                     code                        c_rehash
# calibredb                   chardetect                  codepage                    cron
# calibre-debug               chat                        col                         crontab
# calibre-parallel            chattr                      colcrt                      csplit
# calibre-server              chcon                       colormgr                    ctrlaltdel
# calibre-smtp                chcpu                       colrm                       ctstat
# caller                      check-language-support      column                      cupsaccept
# cam                         chfn                        comm                        cups-browsed
# camera-bug-report           chgpasswd                   command                     cupsctl
# cancel                      chgrp                       compgen                     cupsd
# cancel-rename               chmem                       complete                    cupsdisable
# capsh                       chmod                       compopt                     cupsenable
# captoinfo                   choom                       compose                     cupsfilter
# case                        chown                       con2fbmap                   cupsreject
# cat                         chpasswd                    continue                    cupstestppd
# catman                      chromium                    convert-dtsv0               curl
# cc                          chromium-browser            copilot                     cut
# ccomps                      chroot                      copilot-debug               cvlc
# cd                          chrt                        coproc                      cvtsudoers
# cd-create-profile           chsh                        corelist                    cx18-ctl
# cd-fix-profile              chvt                        cp
#
# danetool                            desktop-file-validate               dpkg
# dash                                devdump                             dpkg-architecture
# date                                devlink                             dpkg-buildapi
# dbus-cleanup-sockets                df                                  dpkg-buildflags
# dbus-daemon                         dh_bash-completion                  dpkg-buildpackage
# dbus-launch                         dhclient                            dpkg-buildtree
# dbus-monitor                        dhclient-script                     dpkg-checkbuilddeps
# dbus-run-session                    dh_installxmlcatalogs               dpkg-deb
# dbus-send                           dh_numpy3                           dpkg-distaddfile
# dbus-update-activation-environment  dh_python3-ply                      dpkg-divert
# dbus-uuidgen                        diff                                dpkg-genbuildinfo
# dc                                  diff3                               dpkg-genchanges
# dcb                                 diffimg                             dpkg-gencontrol
# dconf                               dijkstra                            dpkg-gensymbols
# dd                                  dillo                               dpkg-maintscript-helper
# ddcmon                              dillo-install-hyphenation           dpkg-mergechangelogs
# deallocvt                           dir                                 dpkg-name
# debconf                             dircolors                           dpkg-parsechangelog
# debconf-apt-progress                dirmngr                             dpkg-preconfigure
# debconf-communicate                 dirmngr-client                      dpkg-query
# debconf-copydb                      dirname                             dpkg-realpath
#
# e2freefrag            ebook-meta            edit                  encguess              esgenerate            exfat2img
# e2fsck                ebook-polish          editor                env                   eslint                exfatlabel
# e2image               ebook-viewer          editres               envsubst              esparse               exifautotran
# e2label               ebtables              eepdump               eom                   espeak                exit
# e2mmpstatus           ebtables-nft          eepflash.sh           eps2eps               espeak-ng             exonpairs
# e2scrub               ebtables-nft-restore  eepmake               epylint               esvalidate            expand
# e2scrub_all           ebtables-nft-save     egrep                 eqn                   ethtool               expiry
# e2undo                ebtables-restore      eject                 era_check             eval                  export
# e4crypt               ebtables-save         elfedit               era_dump              evince                expr
# e4defrag              ebtables-translate    elif                  era_invalidate        evince-previewer
# ebook-convert         echo                  else                  era_restore           evince-thumbnailer
# ebook-device          ed                    enable                esac                  ex
# ebook-edit            edgepaint             enc2xs                escodegen             exec
#
# f2py                   fbstat                 fetch-ebook-metadata   fio_generate_plots     fsck.exfat
# f2py3                  fbsvcmgr               ffmpeg                 fio-genzipf            fsck.ext2
# f2py3.11               fbtest                 ffplay                 fio_jsonplus_clat2csv  fsck.ext3
# factor                 fc                     ffprobe                fio-verify-state       fsck.ext4
# faillock               fc-cache               fg                     firefox                fsck.fat
# faillog                fc-cat                 fgconsole              fixparts               fsck.minix
# faked-sysv             fc-conflist            fgrep                  flashrom               fsck.msdos
# faked-tcp              fc-list                fi                     flask                  fsck.vfat
# fake-hwclock           fc-match               file                   flock                  fsfreeze
# fakeroot               fc-pattern             file2brl               fmt                    fstab-decode
# fakeroot-sysv          fc-query               filefrag               fold                   fstrim
# fakeroot-tcp           fc-scan                fincore                fonttosfnt             function
# fallocate              fc-validate            find                   foomatic-rip           funzip
# false                  fdisk                  findfs                 for                    fuser
# fathom                 fdp                    findmnt                forge                  fusermount
# fatlabel               fdtdump                fio                    free                   fusermount3
# fbcli                  fdtget                 fio2gnuplot            fsadm
# fbd-theme-validate     fdtoverlay             fio-btrace2fio         fsck
# fbset                  fdtput                 fio-dedupe             fsck.cramfs
#
# g++                       geany                     git-upload-pack           gpg-zip                   gslj
# g++-12                    gencat                    glib-compile-schemas      gpic                      gslp
# galculator                genfio                    gmake                     gpiodetect                gsnd
# gamma4scanimage           genisoimage               gml2gv                    gpiofind                  gtbl
# gapplication              genl                      gnome-disk-image-mounter  gpioget                   gtf
# gatttool                  geqn                      gnome-disks               gpioinfo                  gtk-nop
# gbak                      getcap                    gnome-help                gpiomon                   gtk-update-icon-cache
# gc                        getcifsacl                gnome-keyring             gpioset                   gts2dxf
# gcc                       getconf                   gnome-keyring-3           gpre                      gts2oogl
# gcc-12                    get-edid                  gnome-keyring-daemon      gprof                     gts2stl
# gcc-ar                    geteltorito               gnome-menus-blacklist     gprofng                   gts2xyz
# gcc-ar-12                 getent                    gnome-www-browser         graphml2gv                gtscheck
# gcc-nm                    getfacl                   gnutls-cli                grep                      gtscompare
# gcc-nm-12                 getkeycodes               gnutls-cli-debug          gresource                 gts-config
# gcc-ranlib                get_objgraph              gnutls-serv               grim                      gtstemplate
# gcc-ranlib-12             getopt                    gold                      groff                     gui-pkinst
# gcore                     getopts                   gp-archive                grog                      gui-updater
# gcov                      getpcaps                  gparted                   grops                     gunzip
# gcov-12                   gettext                   gpasswd                   grotty                    gv2gml
# gcov-dump                 gettext.sh                gp-collect-app            groupadd                  gv2gxl
# gcov-dump-12              getty                     gp-display-html           groupdel                  gvcolor
#
# h2ph                   hdmi-audio-select      hostname               hp-levels              hp-timedate
# h2xs                   head                   hostnamectl            hp-logcapture          html2markdown
# halt                   help                   hp-align               hp-makeuri             html2markdown.py3
# handlebars             helpztags              hp-check               hp-pkservice           htop
# hardlink               hex2hcd                hp-clean               hp-plugin              httpx
# hash                   hexdump                hp-colorcal            hp-probe               hwclock
# hciattach              history                hp-config_usb_printer  hp-query
# hciconfig              hmm-assembler.pl       hp-doctor              hp-scan
# hcitool                hmm-info               hp-firmware            hp-setup
# hd                     hostid                 hp-info                hp-testpage
#
# i2cdetect                    install-sgmlcatalog          ipmaddr                      ir-ctl
# i2cdump                      instmodsh                    ippevepcl                    ischroot
# i2cget                       invoke-rc.d                  ippeveprinter                isodump
# i2cset                       ionice                       ippeveps                     isoinfo
# i2c-stub-from-dump           ip                           ippfind                      isosize
# i2ctransfer                  ip6tables                    ipptool                      isovfy
# iceauth                      ip6tables-apply              ipp-usb                      ispell-autobuildhash
# iconv                        ip6tables-legacy             iptables                     ispell-wrapper
# iconvconfig                  ip6tables-legacy-restore     iptables-apply               isql-fb
# id                           ip6tables-legacy-save        iptables-legacy              istanbul
# iecset                       ip6tables-nft                iptables-legacy-restore      isympy
# if                           ip6tables-nft-restore        iptables-legacy-save         isympy3
# ifconfig                     ip6tables-nft-save           iptables-nft                 ivtv-ctl
# iio-sensor-proxy             ip6tables-restore            iptables-nft-restore         iw
# in                           ip6tables-restore-translate  iptables-nft-save            iwconfig
# infocmp                      ip6tables-save               iptables-restore             iwevent
# infotocap                    ip6tables-translate          iptables-restore-translate   iwgetid
# init                         ipa_verify                   iptables-save                iwlist
# insmod                       ipcmk                        iptables-translate           iwpriv
# install                      ipcrm                        iptables-xml                 iwspy
# installkernel                ipcs                         iptunnel
#
# jar              jcmd             jfr              jmod             jpegtran         json5            jstatd
# jarsigner        jconsole         jhsdb            jobs             jps              jsonpointer      js-yaml
# java             jdb              jimage           join             jrunscript       json_pp          jupyter-execute
# javac            jdeprscan        jinfo            journalctl       js               jsonschema
# javadoc          jdeps            jlink            jpackage         jsesc            jstack
# javap            jexec            jmap             jpegexiforient   jshell           jstat
#
# kactivities-cli      kbxutil              keyctl               killall              kpackagelauncherqml  kturtle
# kanshi               kcookiejar5          key.dns_resolver     killall5             kpackagetool5        kvm
# kbdinfo              kded5                keytool              kmod                 kquitapp5            kwalletd5
# kbd_mode             kde-geo-uri-handler  kglobalaccel5        kmsblank             kreadconfig5         kwallet-query
# kbdrate              kdtc                 kiconfinder5         kmsprint             ktelnetservice5      kwriteconfig5
# kbuildsycoca5        kernel-install       kill                 kmstest              ktrash5
#
# l2ping                      linux-version               lpstat                      lvmdump
# l2test                      listres                     lrf2lrs                     lvmpolld
# labwc                       ln                          lrfviewer                   lvmsadc
# labwc-pi                    lneato                      lrs2lrf                     lvmsar
# labwc-prompt                lnstat                      ls                          lvreduce
# laptop-detect               loadkeys                    lsattr                      lvremove
# last                        loadunimap                  lsblk                       lvrename
# lastb                       lobase                      lsb_release                 lvresize
# lastlog                     local                       lscpu                       lvs
# lc-compliance               localc                      lsfd                        lvscan
# lcf                         locale                      lsinitramfs                 lwrespawn
# ld                          localectl                   lsipc                       lxappearance
# ldattach                    localedef                   lsirq                       lxclipboard
# ld.bfd                      locale-gen                  lslocks                     lxde-logout
# ldconfig                    lodraw                      lslogins                    lxhotkey
# ldd                         loffice                     lsmdev                      lxpanel
# ld.gold                     lofromtemplate              lsmem                       lxpanelctl
# ld.so                       logger                      lsmod                       lxpolkit
# lefty                       logilab-pytest              lsns                        lxrandr
# less                        login                       lsof                        lxsession
# lessecho                    loginctl                    lspci                       lxsession-db
# lessfile                    logname                     lspgpot                     lxsession-default
# lesskey                     logout                      lsusb                       lxsession-default-terminal
# lesspipe                    logrotate                   lto-dump                    lxsession-edit
# let                         logsave                     lto-dump-12                 lxsession-logout
# lexgrog                     loimpress                   lua                         lxsession-xdg-autostart
# libcamerify                 lomath                      lua5.1                      lxtask
# libgvc6-config-update       look                        luac                        lxterminal
# libinput                    losetup                     luac5.1                     lynx
# libnetcfg                   loweb                       luajit                      lzcat
# libreoffice                 lowntfs-3g                  luit                        lzcmp
# libvirtd                    lowriter                    lvchange                    lzdiff
# lightdm                     lp                          lvconvert                   lzegrep
# lightdm-gtk-greeter         lpadmin                     lvcreate                    lzfgrep
# link                        lp-connection-editor        lvdisplay                   lzgrep
# linux32                     lpinfo                      lvextend                    lzless
# linux64                     lpmove                      lvm                         lzma
# linux-check-removal         lpoptions                   lvmconfig                   lzmainfo
# linux-update-symlinks       lp_solve                    lvmdiskscan                 lzmore
#
# mac2unix                          mkdir                             mkzftree
# machinectl                        mkdosfs                           mm2gv
# make                              mke2fs                            mmcli
# make-first-existing-target        mkfifo                            modeline2fb
# make-ssl-cert                     mkfontdir                         modinfo
# man                               mkfontscale                       modprobe
# mandb                             mkfs                              monitor-sensor
# manpath                           mkfs.bfs                          more
# man-recode                        mkfs.cramfs                       mount
# mapfile                           mkfs.exfat                        mount.cifs
# mapscrn                           mkfs.ext2                         mount.fuse
# markdown-calibre                  mkfs.ext3                         mount.fuse3
# markdown-it                       mkfs.ext4                         mount.lowntfs-3g
# markdown_py                       mkfs.fat                          mount.nfs
# mate-polkit                       mkfs.minix                        mount.nfs4
# mawk                              mkfs.msdos                        mount.ntfs
# mbimcli                           mkfs.ntfs                         mount.ntfs-3g
# mbim-network                      mkfs.vfat                         mountpoint
# mcookie                           mkhomedir_helper                  mount.smb3
# md5sum                            mkinitramfs                       mountstats
# md5sum.textutils                  mkisofs                           mousepad
# mdevctl                           mklost+found                      mpeg2desc
# media-ctl                         mk_modmap                         mpris-proxy
# memusage                          mknod                             mt
# memusagestat                      mkntfs                            mt-gnu
# mesa-overlay-control.py           mkswap                            mtrace
# mesg                              mktemp                            mu-editor
# meson                             mkvextract                        mv
# migrate-pubring-from-classic-gpg  mkvinfo                           mypy
# mii-tool                          mkvmerge                          mypyc
# mingle                            mkvpropedit
#
# namei           neqn            nfsiostat       nm-online       nologin         nstat           ntfsfix         ntfsusermap
# nameif          netcat          nfsstat         nmtui           nop             ntfs-3g         ntfsinfo        ntfswipe
# nano            netscsid        nft             nmtui-connect   normalizer      ntfs-3g.probe   ntfslabel       nudatus
# nanoid          netstat         ngettext        nmtui-edit      notify-send     ntfscat         ntfsls          numfmt
# nawk            networkctl      nice            nmtui-hostname  npm             ntfsclone       ntfsmove        nvlc
# nbackup         newgrp          ninja           node            npm-arborist    ntfscluster     ntfsrecover     nyc
# nc              newusers        nisdomainname   node-coveralls  nproc           ntfscmp         ntfsresize
# ncdu            nfnl_osf        nl              node-gyp        npx             ntfscp          ntfssecaudit
# nc.openbsd      nfsconf         nm              nodejs          nroff           ntfsdecrypt     ntfstruncate
# neato           nfsidmap        nmcli           nohup           nsenter         ntfsfallocate   ntfsundelete
#
# obamenu          objdump          open             openbox-session  openvt           otpset
# obconf           obxprop          openbox          opener           optipng          overlaycheck
# obexctl          ocsptool         openbox-lxde     openocd          osage            ovmerge
# objcopy          od               openbox-lxde-pi  openssl          osirrox
#
# p11-kit                     perlthanks                  pod2man                     pvresize
# p11tool                     pf2afm                      pod2text                    pvs
# p7zip                       pfbtopfa                    pod2usage                   pvscan
# pacat                       pgrep                       podchecker                  pw-cat
# pacmd                       pgzrun                      poff                        pwck
# pacote                      pic                         pon                         pw-cli
# pactl                       piclone                     popd                        pw-config
# padsp                       pico                        portablectl                 pw-container
# pager                       piconv                      poweroff                    pwconv
# pa-info                     pidof                       ppdc                        pwd
# pam-auth-update             pidwait                     ppdhtml                     pw-dot
# pam_getenv                  pig2vcd                     ppdi                        pw-dsdplay
# pam_namespace_helper        pigpiod                     ppdmerge                    pw-dump
# pamon                       pi-gpk-dbus-service         ppdpo                       pwdx
# pam_timestamp_check         pi-gpk-install-local-file   pphs                        pw-encplay
# pandoc                      pi-gpk-log                  pppdump                     pwhistory_helper
# paperconf                   pi-gpk-prefs                pppoe-discovery             pw-link
# paperconfig                 pi-gpk-update-viewer        pppstats                    pw-loopback
# paplay                      pi-greeter                  pprompt.sh                  pw-metadata
# parec                       pigs                        pr                          pw-mididump
# parecord                    pinctrl                     preconv                     pw-midiplay
# parse-edid                  pinentry                    preparetips5                pw-midirecord
# parted                      pinentry-curses             print                       pw-mon
# partprobe                   pinentry-gnome3             printafm                    pw-play
# partx                       pinentry-x11                printenv                    pw-profiler
# passwd                      ping                        printf                      pw-record
# paste                       ping4                       prlimit                     pw-reserve
# pastebinit                  ping6                       protocoltojson              pwrkey
# pasuspender                 pinky                       prove                       pw-top
# patch                       pinout                      proxy                       pwunconv
# patch-hmm.pl                pintest                     prtstat                     py3clean
# patchwork                   pip                         prune                       py3compile
# pathchk                     pip3                        ps                          py3versions
# pax11publish                pip3.11                     ps2ascii                    py7zr
# pbget                       pi-packages                 ps2epsi                     pyav
# pbput                       pipanel                     ps2pdf                      pybabel
# pbputs                      pipenv                      ps2pdf12                    pybabel-python3
# pcmanfm                     pipenv-resolver             ps2pdf13                    pydoc
# pdata_tools                 pipewire                    ps2pdf14                    pydoc3
# pdb3                        pipewire-aes67              ps2pdfwr                    pydoc3.11
# pdb3.11                     pipewire-avb                ps2ps                       pyflakes3
# pdf2dsc                     pipewire-pulse              ps2ps2                      pygettext3
# pdf2ps                      pishutdown                  ps2txt                      pygettext3.11
# pdfattach                   pivot_root                  psfaddtable                 pygmentize
# pdfdetach                   piwiz                       psfgettable                 pylint
# pdffonts                    pkaction                    psfstriptable               pylint-config
# pdfimages                   pkcheck                     psfxtable                   pylupdate6
# pdfinfo                     pkexec                      psktool                     pyreverse
# pdfseparate                 pkgconf                     pslog                       pysemver
# pdfsig                      pkg-config                  pstree                      pyserial-miniterm
# pdftocairo                  pkill                       pstree.x11                  pyserial-ports
# pdftohtml                   pkla-admin-identities       ptar                        python
# pdftoppm                    pkla-check-authorization    ptardiff                    python3
# pdftops                     pkttyagent                  ptargrep                    python3.11
# pdftotext                   pl2pm                       ptx                         python3.11-config
# pdfunite                    pldd                        pulseaudio                  python3.11-coverage
# peekfd                      plipconfig                  pushd                       python3-config
# perl                        plog                        pvchange                    python3-coverage
#
# qcam                 qemu-nbd             qemu-system-aarch64  qmi-firmware-update  qt5ct                qvlc
# qemu-img             qemu-pr-helper       qemu-system-arm      qmi-network          qt-faststart
# qemu-io              qemu-storage-daemon  qmicli               qrcode-terminal      qtpy
#
# raindrop                    remove-default-wordlist     rpcdebug                    rst2html4
# ranlib                      remove-shell                rpcgen                      rst2html5
# rarp                        rename.ul                   rpc.gssd                    rst2latex
# raspi-config                rename-user                 rpc.idmapd                  rst2man
# raspi-gpio                  renice                      rpcinfo                     rst2odt
# raspinfo                    request-key                 rpc.statd                   rst2odt_prepstyles
# rasputin                    reset                       rpc.svcgssd                 rst2pseudoxml
# rasterizer                  resize2fs                   rpi-bootloader-key-convert  rst2s5
# rbash                       resizepart                  rpicam-hello                rst2xetex
# rc_gui                      return                      rpicam-jpeg                 rst2xml
# rctest                      rev                         rpicam-raw                  rst-buildhtml
# rdjpgcom                    rfcomm                      rpicam-still                rstpep2html
# rdma                        rfkill                      rpicam-vid                  rsync
# rds-ctl                     rgrep                       rpi-connect                 rsync-ssl
# read                        rimraf                      rpi-connectd                rtacct
# readarray                   rm                          rpi-connect-env             rtcwake
# readelf                     rmdir                       rpi-eeprom-config           rtkitctl
# readlink                    rmiregistry                 rpi-eeprom-digest           rtmon
# readom                      rmmod                       rpi-eeprom-update           rtstat
# readonly                    rmt                         rpi-imager                  runcon
# readprofile                 rmt-tar                     rpinters                    runlevel
# realpath                    rnano                       rpi-otp-private-key         run-mailcap
# reboot                      route                       rpi-sign-bootcode           run-parts
# red                         routel                      rpi-update                  runuser
# regjsparser                 rp-bookshelf                rp-prefapps                 rview
# remote-viewer               rpcbind                     rrsync                      rvlc
# remove-default-ispell       rpcctl                      rst2html
#
# saned                           setvtrgb                        splitfont                       swapoff
# sane-find-scanner               setxkbmap                       sprof                           swapon
# savelog                         sfdisk                          spumux                          swayidle
# sbout                           sfdp                            spuunmux                        swaylock
# sbtest                          sftp                            squeekboard                     switch_root
# scalar                          sg                              squeekboard-restyled            swtpm
# scanimage                       sgdisk                          squiggle                        swtpm_bios
# sccmap                          sh                              srptool                         swtpm_cert
# scp                             sha1sum                         ss                              swtpm_ioctl
# scp-dbus-service                sha224sum                       ssh                             swtpm_localca
# screendump                      sha256sum                       ssh-add                         swtpm_setup
# script                          sha384sum                       ssh-agent                       symilar
# scriptlive                      sha512sum                       ssh-argv0                       sync
# scriptreplay                    shadowconfig                    ssh-copy-id                     sysctl
# scrot                           shasum                          sshd                            systemctl
# sdiff                           shift                           ssh-import-id                   systemd
# sdptool                         shopt                           ssh-import-id-gh                systemd-analyze
# sed                             showconsolefont                 ssh-import-id-lp                systemd-ask-password
# see                             showkey                         ssh-keygen                      systemd-cat
# select                          showmount                       ssh-keyscan                     systemd-cgls
# select-default-ispell           showrgb                         startlxde                       systemd-cgtop
# select-default-iwrap            shred                           startlxde-pi                    systemd-creds
# select-default-wordlist         shuf                            start-pulseaudio-x11            systemd-cryptenroll
# select-editor                   shutdown                        start-statd                     systemd-delta
# semver                          size                            start-stop-daemon               systemd-detect-virt
# send2trash                      skill                           startx                          systemd-dissect
# sensible-browser                slabtop                         stat                            systemd-escape
# sensible-editor                 slattach                        stdbuf                          systemd-firstboot
# sensible-pager                  sleep                           stl2gts                         systemd-hwdb
# seq                             slogin                          strace                          systemd-id128
# serialver                       smb2-quota                      strace-log-merge                systemd-inhibit
# service                         smbinfo                         streamzip                       systemd-machine-id-setup
# sessreg                         sm-notify                       strings                         systemd-mount
# set                             snap-hmm                        strip                           systemd-notify
# setarch                         snice                           stty                            systemd-nspawn
# setcap                          soelim                          stubgen                         systemd-path
# setcifsacl                      soffice                         stubtest                        systemd-repart
# setfacl                         sort                            su                              systemd-run
# setfont                         sotruss                         sudo                            systemd-socket-activate
# setkeycodes                     source                          sudoedit                        systemd-stdio-bridge
# setleds                         spa-acp-tool                    sudo_logsrvd                    systemd-sysext
# setlogcons                      spa-inspect                     sudopwd                         systemd-sysusers
# setmetamode                     spa-json-dump                   sudoreplay                      systemd-tmpfiles
# setpci                          spa-monitor                     sudo_sendlog                    systemd-tty-ask-password-agent
# setpriv                         spa-resample                    sulogin                         systemd-umount
# setsid                          spd-conf                        sum                             systemsettings
# setterm                         speaker-test                    suspend                         systemsettings5
# setupcon                        speak-ng                        svgpp
# setup_env                       splain                          svlc
# setvesablank                    split                           swaplabel
#
# tabs                tc                  thin_ls             tipc                tr                  ttf2svg
# tac                 tee                 thin_metadata_size  tjbench             transform           tty
# tail                telinit             thin_repair         tldr                transmission-gtk    tune2fs
# tap                 tempfile            thin_restore        tldr-hs             trap                tune.exfat
# tape                terser              thin_rmap           tload               tred                twopi
# tap-mocha-reporter  test                thin_trim           toc2cddb            tree                type
# tap-parser          th-cmd              thonny              toc2cue             troff               typeset
# tar                 thd                 tic                 toe                 true                tzselect
# tarcat              then                time                top                 truncate
# tasksel             thin_check          timedatectl         touch               trust
# taskset             thin_delta          timeout             tput                tset
# tbl                 thin_dump           times               tqdm                tsort
#
# ucf                         unexpand                    update-alternatives         update-mime-database
# ucfq                        unflatten                   update-ca-certificates      update-passwd
# ucfr                        unicode_start               update-catalog              update-pciids
# uclampset                   unicode_stop                update-cracklib             update-rc.d
# ucs2any                     uniq                        update-default-aspell       update-shells
# udevadm                     unix2dos                    update-default-ispell       update-xmlcatalog
# udisksctl                   unix2mac                    update-default-wordlist     upower
# uflash                      unix_chkpwd                 update-desktop-database     uptime
# ul                          unix_update                 update-dictcommon-aspell    usb-devices
# ulimit                      unlink                      update-dictcommon-hunspell  usbhid-dump
# umask                       unlzma                      update-fonts-alias          usb_modeswitch
# umax_pp                     unmkinitramfs               update-fonts-dir            usb_modeswitch_dispatcher
# umount                      unopkg                      update-fonts-scale          usbreset
# umount.nfs                  unset                       update-gsfontmap            useradd
# umount.nfs4                 unshare                     update-icon-caches          userdel
# umount.udisks2              until                       update-inetd                usermod
# unalias                     unxz                        update-initramfs            users
# uname                       unzip                       update-java-alternatives    utmpdump
# uncompress                  unzipsfx                    update-locale               uuid
# undill                      unzstd                      update-mime
#
# v4l2-compliance         vgcreate                viewres                 virt-ssh-helper         vnclicense
# v4l2-ctl                vgdisplay               vigr                    virtualenv              vnclicensewiz
# v4l2-dbg                vgexport                vimdot                  virtualenv-clone        vncpamhelper
# v4l2-sysfs-path         vgextend                vim.tiny                virt-viewer             vncpasswd
# validlocale             vgimport                vipw                    virt-xml                vncserver
# vcgencmd                vgimportclone           virsh                   virt-xml-validate       vncserverui
# vclog                   vgmerge                 virt-admin              visudo                  vncserver-virtual
# vcmailbox               vgmknodes               virt-clone              vkcube                  vncserver-virtuald
# vcstime                 vgreduce                virt-host-validate      vkcubepp                vncserver-x11
# vdir                    vgremove                virt-install            vkcube-wayland          vncserver-x11-core
# vdpa                    vgrename                virtlockd               vlc                     vncserver-x11-serviced
# vgcfgbackup             vgs                     virtlogd                vlc-wrapper             vncviewer
# vgcfgrestore            vgscan                  virt-manager            vmstat                  vulkaninfo
# vgchange                vgsplit                 virt-pki-query-dn       vncagent
# vgck                    vi                      virt-pki-validate       vncfopshelper
# vgconvert               view                    virt-qemu-run           vncinitconfig
#
# w                        wayvncctl                wfrespawn                whoami                   wpa_supplicant
# wait                     wayvnc-generate-keys.sh  wget                     wipefs                   wpctl
# wall                     wayvnc-run.sh            whatis                   wireplumber              wpexec
# watch                    wc                       whereis                  wlopm                    write
# watchgnupg               wdctl                    which                    wlr-randr                wrjpgcom
# wayfire                  web2disk                 which.debianutils        wodim                    wscat
# wayfire-pi               webpack                  while                    wpa_action               wsdump
# wayvnc                   wfpanelctl               whiptail                 wpa_cli                  www-browser
# wayvnc-control.py        wf-panel-pi              who                      wpa_passphrase
#
# xarchiver             xdg-settings          xkbbell               xmllint               xsetmode              x-window-manager
# xargs                 xdg-user-dir          xkbcomp               xmlstarlet            xsetpointer           xwininfo
# xauth                 xdg-user-dirs-update  xkbevd                xmodmap               xsetroot              x-www-browser
# xcmsdb                xdpyinfo              xkbprint              xorrecord             xsettingsd            xz
# xcompmgr              xdriinfo              xkbvleds              xorriso               xstdcmap              xzcat
# xdg-dbus-proxy        xev                   xkbwatch              xorrisofs             xsubpp                xzcmp
# xdg-desktop-icon      xfallback.sh          xkeystone             xprop                 xtables-legacy-multi  xzdiff
# xdg-desktop-menu      xfd                   xkill                 xrandr                xtables-monitor       xzegrep
# xdg-email             xfontsel              xlsatoms              xrdb                  xtables-nft-multi     xzfgrep
# xdg-icon-resource     xgamma                xlsclients            xrefresh              x-terminal-emulator   xzgrep
# xdg-mime              xhost                 xlsfonts              xsel                  xvidtune              xzless
# xdg-open              xinit                 xmessage              x-session-manager     xvinfo                xzmore
# xdg-screensaver       xinput                xmlcatalog            xset                  xwayland-xauth
#
# yelp          yes           ypdomainname
#
# zcat         zdump        zenoty       zforce       zip          zipgrep      zipsplit     znew         zstd         zstdless
# zcmp         zegrep       zff2gff3.pl  zgrep        zipcloak     zipinfo      zless        zoe-loop     zstdcat      zstdmt
# zdiff        zenity       zfgrep       zic          zipdetails   zipnote      zmore        zramctl      zstdgrep
# ---

# %% [markdown]
# ## Command HELP

# %%
import os
import subprocess

line="--------------------------------------------------------------------------------"

# Load bash_commands.txt and break into separate words
with open('bash_commands.txt', 'r') as f:
    content = f.read()
    words = content.split()
    for word in words:
        if word != "" and word != "--------------------------------------------------------------------------------":
            print(f"tldr {word} >./tldr/{word}.txt")




    # # Create tldr directory if it doesn't exist
    # os.makedirs('./tldr', exist_ok=True)
    # # Generate tldr commands for each word
    # for word in words:
    #     if word and word != line and word != "":
    #         subprocess.run(f"tldr {word} >./tldr/{word}.txt 2>&1", shell=True)
    # print("tldr Done")

    # # Create help directory if it doesn't exist', exist_ok=True)
    # os.makedirs('./help', exist_ok=True)
    # # Generate help commands for each word
    # for word in words:
    #     if word and word != line and word != "":
    #         subprocess.run(f"{word} --help >./help/{word}.txt 2>&1", shell=True)
    # print("help Done")

    # # Create man directory if it doesn't exist
    # os.makedirs('./man', exist_ok=True)
    # # Generate man commands for each word
    # for word in words:
    #     if word and word != line and word != "":
    #         subprocess.run(f"man {word} >./man/{word}.txt 2>&1", shell=True)
    # print("man Done")
# Out:
# tldr aa-enabled >./tldr/aa-enabled.txt
# tldr aarch64-linux-gnu-nm >./tldr/aarch64-linux-gnu-nm.txt
# tldr ant >./tldr/ant.txt
# tldr aa-exec >./tldr/aa-exec.txt
# tldr aarch64-linux-gnu-objcopy >./tldr/aarch64-linux-gnu-objcopy.txt
# tldr aplay >./tldr/aplay.txt
# tldr aa-features-abi >./tldr/aa-features-abi.txt
# tldr aarch64-linux-gnu-objdump >./tldr/aarch64-linux-gnu-objdump.txt
# tldr aplaymidi >./tldr/aplaymidi.txt
# tldr aarch64-linux-gnu-addr2line >./tldr/aarch64-linux-gnu-addr2line.txt
# tldr aarch64-linux-gnu-pkgconf >./tldr/aarch64-linux-gnu-pkgconf.txt
# tldr apparmor_parser >./tldr/apparmor_parser.txt
# tldr aarch64-linux-gnu-ar >./tldr/aarch64-linux-gnu-ar.txt
# tldr aarch64-linux-gnu-pkg-config >./tldr/aarch64-linux-gnu-pkg-config.txt
# tldr apparmor_status >./tldr/apparmor_status.txt
# tldr aarch64-linux-gnu-as >./tldr/aarch64-linux-gnu-as.txt
# tldr aarch64-linux-gnu-python3.11-config >./tldr/aarch64-linux-gnu-python3.11-config.txt
# tldr applygnupgdefaults >./tldr/applygnupgdefaults.txt
# tldr aarch64-linux-gnu-c++filt >./tldr/aarch64-linux-gnu-c++filt.txt
# tldr aarch64-linux-gnu-python3-config >./tldr/aarch64-linux-gnu-python3-config.txt
# tldr appres >./tldr/appres.txt
# tldr aarch64-linux-gnu-cpp >./tldr/aarch64-linux-gnu-cpp.txt
# tldr aarch64-linux-gnu-ranlib >./tldr/aarch64-linux-gnu-ranlib.txt
# tldr apropos >./tldr/apropos.txt
# tldr aarch64-linux-gnu-cpp-12 >./tldr/aarch64-linux-gnu-cpp-12.txt
# tldr aarch64-linux-gnu-readelf >./tldr/aarch64-linux-gnu-readelf.txt
# tldr apt >./tldr/apt.txt
# tldr aarch64-linux-gnu-dwp >./tldr/aarch64-linux-gnu-dwp.txt
# tldr aarch64-linux-gnu-size >./tldr/aarch64-linux-gnu-size.txt
# tldr apt-cache >./tldr/apt-cache.txt
# tldr aarch64-linux-gnu-elfedit >./tldr/aarch64-linux-gnu-elfedit.txt
# tldr aarch64-linux-gnu-strings >./tldr/aarch64-linux-gnu-strings.txt
# tldr apt-cdrom >./tldr/apt-cdrom.txt
# tldr aarch64-linux-gnu-g++ >./tldr/aarch64-linux-gnu-g++.txt
# tldr aarch64-linux-gnu-strip >./tldr/aarch64-linux-gnu-strip.txt
# tldr apt-config >./tldr/apt-config.txt
# tldr aarch64-linux-gnu-g++-12 >./tldr/aarch64-linux-gnu-g++-12.txt
# tldr aa-remove-unknown >./tldr/aa-remove-unknown.txt
# tldr apt-extracttemplates >./tldr/apt-extracttemplates.txt
# tldr aarch64-linux-gnu-gcc >./tldr/aarch64-linux-gnu-gcc.txt
# tldr aa-status >./tldr/aa-status.txt
# tldr apt-ftparchive >./tldr/apt-ftparchive.txt
# tldr aarch64-linux-gnu-gcc-12 >./tldr/aarch64-linux-gnu-gcc-12.txt
# tldr aa-teardown >./tldr/aa-teardown.txt
# tldr apt-get >./tldr/apt-get.txt
# tldr aarch64-linux-gnu-gcc-ar >./tldr/aarch64-linux-gnu-gcc-ar.txt
# tldr accessdb >./tldr/accessdb.txt
# tldr apt-key >./tldr/apt-key.txt
# tldr aarch64-linux-gnu-gcc-ar-12 >./tldr/aarch64-linux-gnu-gcc-ar-12.txt
# tldr aconnect >./tldr/aconnect.txt
# tldr apt-listchanges >./tldr/apt-listchanges.txt
# tldr aarch64-linux-gnu-gcc-nm >./tldr/aarch64-linux-gnu-gcc-nm.txt
# tldr acorn >./tldr/acorn.txt
# tldr apt-mark >./tldr/apt-mark.txt
# tldr aarch64-linux-gnu-gcc-nm-12 >./tldr/aarch64-linux-gnu-gcc-nm-12.txt
# tldr acyclic >./tldr/acyclic.txt
# tldr apt-sortpkgs >./tldr/apt-sortpkgs.txt
# tldr aarch64-linux-gnu-gcc-ranlib >./tldr/aarch64-linux-gnu-gcc-ranlib.txt
# tldr addgnupghome >./tldr/addgnupghome.txt
# tldr ar >./tldr/ar.txt
# tldr aarch64-linux-gnu-gcc-ranlib-12 >./tldr/aarch64-linux-gnu-gcc-ranlib-12.txt
# tldr addgroup >./tldr/addgroup.txt
# tldr arborist >./tldr/arborist.txt
# tldr aarch64-linux-gnu-gcov >./tldr/aarch64-linux-gnu-gcov.txt
# tldr addpart >./tldr/addpart.txt
# tldr arch >./tldr/arch.txt
# tldr aarch64-linux-gnu-gcov-12 >./tldr/aarch64-linux-gnu-gcov-12.txt
# tldr addr2line >./tldr/addr2line.txt
# tldr arecord >./tldr/arecord.txt
# tldr aarch64-linux-gnu-gcov-dump >./tldr/aarch64-linux-gnu-gcov-dump.txt
# tldr add-shell >./tldr/add-shell.txt
# tldr arecordmidi >./tldr/arecordmidi.txt
# tldr aarch64-linux-gnu-gcov-dump-12 >./tldr/aarch64-linux-gnu-gcov-dump-12.txt
# tldr adduser >./tldr/adduser.txt
# tldr arp >./tldr/arp.txt
# tldr aarch64-linux-gnu-gcov-tool >./tldr/aarch64-linux-gnu-gcov-tool.txt
# tldr agetty >./tldr/agetty.txt
# tldr arpd >./tldr/arpd.txt
# tldr aarch64-linux-gnu-gcov-tool-12 >./tldr/aarch64-linux-gnu-gcov-tool-12.txt
# tldr agnostics >./tldr/agnostics.txt
# tldr arptables >./tldr/arptables.txt
# tldr aarch64-linux-gnu-gold >./tldr/aarch64-linux-gnu-gold.txt
# tldr airscan-discover >./tldr/airscan-discover.txt
# tldr arptables-nft >./tldr/arptables-nft.txt
# tldr aarch64-linux-gnu-gp-archive >./tldr/aarch64-linux-gnu-gp-archive.txt
# tldr alacarte >./tldr/alacarte.txt
# tldr arptables-nft-restore >./tldr/arptables-nft-restore.txt
# tldr aarch64-linux-gnu-gp-collect-app >./tldr/aarch64-linux-gnu-gp-collect-app.txt
# tldr alias >./tldr/alias.txt
# tldr arptables-nft-save >./tldr/arptables-nft-save.txt
# tldr aarch64-linux-gnu-gp-display-html >./tldr/aarch64-linux-gnu-gp-display-html.txt
# tldr alsabat >./tldr/alsabat.txt
# tldr arptables-restore >./tldr/arptables-restore.txt
# tldr aarch64-linux-gnu-gp-display-src >./tldr/aarch64-linux-gnu-gp-display-src.txt
# tldr alsabat-test >./tldr/alsabat-test.txt
# tldr arptables-save >./tldr/arptables-save.txt
# tldr aarch64-linux-gnu-gp-display-text >./tldr/aarch64-linux-gnu-gp-display-text.txt
# tldr alsactl >./tldr/alsactl.txt
# tldr as >./tldr/as.txt
# tldr aarch64-linux-gnu-gprof >./tldr/aarch64-linux-gnu-gprof.txt
# tldr alsa-info >./tldr/alsa-info.txt
# tldr aseqdump >./tldr/aseqdump.txt
# tldr aarch64-linux-gnu-gprofng >./tldr/aarch64-linux-gnu-gprofng.txt
# tldr alsaloop >./tldr/alsaloop.txt
# tldr aseqnet >./tldr/aseqnet.txt
# tldr aarch64-linux-gnu-ld >./tldr/aarch64-linux-gnu-ld.txt
# tldr alsamixer >./tldr/alsamixer.txt
# tldr aspell-autobuildhash >./tldr/aspell-autobuildhash.txt
# tldr aarch64-linux-gnu-ld.bfd >./tldr/aarch64-linux-gnu-ld.bfd.txt
# tldr alsatplg >./tldr/alsatplg.txt
# tldr autotouch >./tldr/autotouch.txt
# tldr aarch64-linux-gnu-ld.gold >./tldr/aarch64-linux-gnu-ld.gold.txt
# tldr alsaucm >./tldr/alsaucm.txt
# tldr avahi-daemon >./tldr/avahi-daemon.txt
# tldr aarch64-linux-gnu-lto-dump >./tldr/aarch64-linux-gnu-lto-dump.txt
# tldr amidi >./tldr/amidi.txt
# tldr awk >./tldr/awk.txt
# tldr aarch64-linux-gnu-lto-dump-12 >./tldr/aarch64-linux-gnu-lto-dump-12.txt
# tldr amixer >./tldr/amixer.txt
# tldr axfer >./tldr/axfer.txt
# tldr b2sum >./tldr/b2sum.txt
# tldr bash >./tldr/bash.txt
# tldr bluemoon >./tldr/bluemoon.txt
# tldr busctl >./tldr/busctl.txt
# tldr babeljs >./tldr/babeljs.txt
# tldr bashbug >./tldr/bashbug.txt
# tldr bluetoothctl >./tldr/bluetoothctl.txt
# tldr busybox >./tldr/busybox.txt
# tldr babeljs-7 >./tldr/babeljs-7.txt
# tldr bc >./tldr/bc.txt
# tldr bluetoothd >./tldr/bluetoothd.txt
# tldr bwrap >./tldr/bwrap.txt
# tldr babeljs-7-external-helpers >./tldr/babeljs-7-external-helpers.txt
# tldr bcomps >./tldr/bcomps.txt
# tldr brasero >./tldr/brasero.txt
# tldr bzcat >./tldr/bzcat.txt
# tldr babeljs-7-node >./tldr/babeljs-7-node.txt
# tldr bdftopcf >./tldr/bdftopcf.txt
# tldr break >./tldr/break.txt
# tldr bzcmp >./tldr/bzcmp.txt
# tldr babeljs-7-parser >./tldr/babeljs-7-parser.txt
# tldr bdftruncate >./tldr/bdftruncate.txt
# tldr bridge >./tldr/bridge.txt
# tldr bzdiff >./tldr/bzdiff.txt
# tldr babeljs-external-helpers >./tldr/babeljs-external-helpers.txt
# tldr bg >./tldr/bg.txt
# tldr browserslist >./tldr/browserslist.txt
# tldr bzegrep >./tldr/bzegrep.txt
# tldr babeljs-node >./tldr/babeljs-node.txt
# tldr bind >./tldr/bind.txt
# tldr btattach >./tldr/btattach.txt
# tldr bzexe >./tldr/bzexe.txt
# tldr babeljs-parser >./tldr/babeljs-parser.txt
# tldr blkdeactivate >./tldr/blkdeactivate.txt
# tldr bthelper >./tldr/bthelper.txt
# tldr bzfgrep >./tldr/bzfgrep.txt
# tldr badblocks >./tldr/badblocks.txt
# tldr blkdiscard >./tldr/blkdiscard.txt
# tldr btmgmt >./tldr/btmgmt.txt
# tldr bzgrep >./tldr/bzgrep.txt
# tldr base32 >./tldr/base32.txt
# tldr blkid >./tldr/blkid.txt
# tldr btmon >./tldr/btmon.txt
# tldr bzip2 >./tldr/bzip2.txt
# tldr base64 >./tldr/base64.txt
# tldr blkmapd >./tldr/blkmapd.txt
# tldr btuart >./tldr/btuart.txt
# tldr bzip2recover >./tldr/bzip2recover.txt
# tldr basename >./tldr/basename.txt
# tldr blkzone >./tldr/blkzone.txt
# tldr builtin >./tldr/builtin.txt
# tldr bzless >./tldr/bzless.txt
# tldr basenc >./tldr/basenc.txt
# tldr blockdev >./tldr/blockdev.txt
# tldr bunzip2 >./tldr/bunzip2.txt
# tldr bzmore >./tldr/bzmore.txt
# tldr c++ >./tldr/c++.txt
# tldr cd-iccdump >./tldr/cd-iccdump.txt
# tldr cifscreds >./tldr/cifscreds.txt
# tldr cpan >./tldr/cpan.txt
# tldr c89 >./tldr/c89.txt
# tldr cd-it8 >./tldr/cd-it8.txt
# tldr cifs.idmap >./tldr/cifs.idmap.txt
# tldr cpan5.36-aarch64-linux-gnu >./tldr/cpan5.36-aarch64-linux-gnu.txt
# tldr c89-gcc >./tldr/c89-gcc.txt
# tldr cdrdao >./tldr/cdrdao.txt
# tldr cifs.upcall >./tldr/cifs.upcall.txt
# tldr cpgr >./tldr/cpgr.txt
# tldr c99 >./tldr/c99.txt
# tldr cdrecord >./tldr/cdrecord.txt
# tldr ciptool >./tldr/ciptool.txt
# tldr cpio >./tldr/cpio.txt
# tldr c99-gcc >./tldr/c99-gcc.txt
# tldr cec-compliance >./tldr/cec-compliance.txt
# tldr circo >./tldr/circo.txt
# tldr cpp >./tldr/cpp.txt
# tldr cache_check >./tldr/cache_check.txt
# tldr cec-ctl >./tldr/cec-ctl.txt
# tldr cjpeg >./tldr/cjpeg.txt
# tldr cpp-12 >./tldr/cpp-12.txt
# tldr cache_dump >./tldr/cache_dump.txt
# tldr cec-follower >./tldr/cec-follower.txt
# tldr ckbcomp >./tldr/ckbcomp.txt
# tldr cppw >./tldr/cppw.txt
# tldr cache_metadata_size >./tldr/cache_metadata_size.txt
# tldr certtool >./tldr/certtool.txt
# tldr cksum >./tldr/cksum.txt
# tldr cracklib-check >./tldr/cracklib-check.txt
# tldr cache_repair >./tldr/cache_repair.txt
# tldr cfdisk >./tldr/cfdisk.txt
# tldr clear >./tldr/clear.txt
# tldr cracklib-format >./tldr/cracklib-format.txt
# tldr cache_restore >./tldr/cache_restore.txt
# tldr c++filt >./tldr/c++filt.txt
# tldr clear_console >./tldr/clear_console.txt
# tldr cracklib-packer >./tldr/cracklib-packer.txt
# tldr cache_writeback >./tldr/cache_writeback.txt
# tldr cgdisk >./tldr/cgdisk.txt
# tldr cluster >./tldr/cluster.txt
# tldr cracklib-unpacker >./tldr/cracklib-unpacker.txt
# tldr calibre >./tldr/calibre.txt
# tldr chacl >./tldr/chacl.txt
# tldr cmatrix >./tldr/cmatrix.txt
# tldr create-cracklib-dict >./tldr/create-cracklib-dict.txt
# tldr calibre-complete >./tldr/calibre-complete.txt
# tldr chage >./tldr/chage.txt
# tldr cmp >./tldr/cmp.txt
# tldr create_xauth >./tldr/create_xauth.txt
# tldr calibre-customize >./tldr/calibre-customize.txt
# tldr chardet >./tldr/chardet.txt
# tldr code >./tldr/code.txt
# tldr c_rehash >./tldr/c_rehash.txt
# tldr calibredb >./tldr/calibredb.txt
# tldr chardetect >./tldr/chardetect.txt
# tldr codepage >./tldr/codepage.txt
# tldr cron >./tldr/cron.txt
# tldr calibre-debug >./tldr/calibre-debug.txt
# tldr chat >./tldr/chat.txt
# tldr col >./tldr/col.txt
# tldr crontab >./tldr/crontab.txt
# tldr calibre-parallel >./tldr/calibre-parallel.txt
# tldr chattr >./tldr/chattr.txt
# tldr colcrt >./tldr/colcrt.txt
# tldr csplit >./tldr/csplit.txt
# tldr calibre-server >./tldr/calibre-server.txt
# tldr chcon >./tldr/chcon.txt
# tldr colormgr >./tldr/colormgr.txt
# tldr ctrlaltdel >./tldr/ctrlaltdel.txt
# tldr calibre-smtp >./tldr/calibre-smtp.txt
# tldr chcpu >./tldr/chcpu.txt
# tldr colrm >./tldr/colrm.txt
# tldr ctstat >./tldr/ctstat.txt
# tldr caller >./tldr/caller.txt
# tldr check-language-support >./tldr/check-language-support.txt
# tldr column >./tldr/column.txt
# tldr cupsaccept >./tldr/cupsaccept.txt
# tldr cam >./tldr/cam.txt
# tldr chfn >./tldr/chfn.txt
# tldr comm >./tldr/comm.txt
# tldr cups-browsed >./tldr/cups-browsed.txt
# tldr camera-bug-report >./tldr/camera-bug-report.txt
# tldr chgpasswd >./tldr/chgpasswd.txt
# tldr command >./tldr/command.txt
# tldr cupsctl >./tldr/cupsctl.txt
# tldr cancel >./tldr/cancel.txt
# tldr chgrp >./tldr/chgrp.txt
# tldr compgen >./tldr/compgen.txt
# tldr cupsd >./tldr/cupsd.txt
# tldr cancel-rename >./tldr/cancel-rename.txt
# tldr chmem >./tldr/chmem.txt
# tldr complete >./tldr/complete.txt
# tldr cupsdisable >./tldr/cupsdisable.txt
# tldr capsh >./tldr/capsh.txt
# tldr chmod >./tldr/chmod.txt
# tldr compopt >./tldr/compopt.txt
# tldr cupsenable >./tldr/cupsenable.txt
# tldr captoinfo >./tldr/captoinfo.txt
# tldr choom >./tldr/choom.txt
# tldr compose >./tldr/compose.txt
# tldr cupsfilter >./tldr/cupsfilter.txt
# tldr case >./tldr/case.txt
# tldr chown >./tldr/chown.txt
# tldr con2fbmap >./tldr/con2fbmap.txt
# tldr cupsreject >./tldr/cupsreject.txt
# tldr cat >./tldr/cat.txt
# tldr chpasswd >./tldr/chpasswd.txt
# tldr continue >./tldr/continue.txt
# tldr cupstestppd >./tldr/cupstestppd.txt
# tldr catman >./tldr/catman.txt
# tldr chromium >./tldr/chromium.txt
# tldr convert-dtsv0 >./tldr/convert-dtsv0.txt
# tldr curl >./tldr/curl.txt
# tldr cc >./tldr/cc.txt
# tldr chromium-browser >./tldr/chromium-browser.txt
# tldr copilot >./tldr/copilot.txt
# tldr cut >./tldr/cut.txt
# tldr ccomps >./tldr/ccomps.txt
# tldr chroot >./tldr/chroot.txt
# tldr copilot-debug >./tldr/copilot-debug.txt
# tldr cvlc >./tldr/cvlc.txt
# tldr cd >./tldr/cd.txt
# tldr chrt >./tldr/chrt.txt
# tldr coproc >./tldr/coproc.txt
# tldr cvtsudoers >./tldr/cvtsudoers.txt
# tldr cd-create-profile >./tldr/cd-create-profile.txt
# tldr chsh >./tldr/chsh.txt
# tldr corelist >./tldr/corelist.txt
# tldr cx18-ctl >./tldr/cx18-ctl.txt
# tldr cd-fix-profile >./tldr/cd-fix-profile.txt
# tldr chvt >./tldr/chvt.txt
# tldr cp >./tldr/cp.txt
# tldr danetool >./tldr/danetool.txt
# tldr desktop-file-validate >./tldr/desktop-file-validate.txt
# tldr dpkg >./tldr/dpkg.txt
# tldr dash >./tldr/dash.txt
# tldr devdump >./tldr/devdump.txt
# tldr dpkg-architecture >./tldr/dpkg-architecture.txt
# tldr date >./tldr/date.txt
# tldr devlink >./tldr/devlink.txt
# tldr dpkg-buildapi >./tldr/dpkg-buildapi.txt
# tldr dbus-cleanup-sockets >./tldr/dbus-cleanup-sockets.txt
# tldr df >./tldr/df.txt
# tldr dpkg-buildflags >./tldr/dpkg-buildflags.txt
# tldr dbus-daemon >./tldr/dbus-daemon.txt
# tldr dh_bash-completion >./tldr/dh_bash-completion.txt
# tldr dpkg-buildpackage >./tldr/dpkg-buildpackage.txt
# tldr dbus-launch >./tldr/dbus-launch.txt
# tldr dhclient >./tldr/dhclient.txt
# tldr dpkg-buildtree >./tldr/dpkg-buildtree.txt
# tldr dbus-monitor >./tldr/dbus-monitor.txt
# tldr dhclient-script >./tldr/dhclient-script.txt
# tldr dpkg-checkbuilddeps >./tldr/dpkg-checkbuilddeps.txt
# tldr dbus-run-session >./tldr/dbus-run-session.txt
# tldr dh_installxmlcatalogs >./tldr/dh_installxmlcatalogs.txt
# tldr dpkg-deb >./tldr/dpkg-deb.txt
# tldr dbus-send >./tldr/dbus-send.txt
# tldr dh_numpy3 >./tldr/dh_numpy3.txt
# tldr dpkg-distaddfile >./tldr/dpkg-distaddfile.txt
# tldr dbus-update-activation-environment >./tldr/dbus-update-activation-environment.txt
# tldr dh_python3-ply >./tldr/dh_python3-ply.txt
# tldr dpkg-divert >./tldr/dpkg-divert.txt
# tldr dbus-uuidgen >./tldr/dbus-uuidgen.txt
# tldr diff >./tldr/diff.txt
# tldr dpkg-genbuildinfo >./tldr/dpkg-genbuildinfo.txt
# tldr dc >./tldr/dc.txt
# tldr diff3 >./tldr/diff3.txt
# tldr dpkg-genchanges >./tldr/dpkg-genchanges.txt
# tldr dcb >./tldr/dcb.txt
# tldr diffimg >./tldr/diffimg.txt
# tldr dpkg-gencontrol >./tldr/dpkg-gencontrol.txt
# tldr dconf >./tldr/dconf.txt
# tldr dijkstra >./tldr/dijkstra.txt
# tldr dpkg-gensymbols >./tldr/dpkg-gensymbols.txt
# tldr dd >./tldr/dd.txt
# tldr dillo >./tldr/dillo.txt
# tldr dpkg-maintscript-helper >./tldr/dpkg-maintscript-helper.txt
# tldr ddcmon >./tldr/ddcmon.txt
# tldr dillo-install-hyphenation >./tldr/dillo-install-hyphenation.txt
# tldr dpkg-mergechangelogs >./tldr/dpkg-mergechangelogs.txt
# tldr deallocvt >./tldr/deallocvt.txt
# tldr dir >./tldr/dir.txt
# tldr dpkg-name >./tldr/dpkg-name.txt
# tldr debconf >./tldr/debconf.txt
# tldr dircolors >./tldr/dircolors.txt
# tldr dpkg-parsechangelog >./tldr/dpkg-parsechangelog.txt
# tldr debconf-apt-progress >./tldr/debconf-apt-progress.txt
# tldr dirmngr >./tldr/dirmngr.txt
# tldr dpkg-preconfigure >./tldr/dpkg-preconfigure.txt
# tldr debconf-communicate >./tldr/debconf-communicate.txt
# tldr dirmngr-client >./tldr/dirmngr-client.txt
# tldr dpkg-query >./tldr/dpkg-query.txt
# tldr debconf-copydb >./tldr/debconf-copydb.txt
# tldr dirname >./tldr/dirname.txt
# tldr dpkg-realpath >./tldr/dpkg-realpath.txt
# tldr e2freefrag >./tldr/e2freefrag.txt
# tldr ebook-meta >./tldr/ebook-meta.txt
# tldr edit >./tldr/edit.txt
# tldr encguess >./tldr/encguess.txt
# tldr esgenerate >./tldr/esgenerate.txt
# tldr exfat2img >./tldr/exfat2img.txt
# tldr e2fsck >./tldr/e2fsck.txt
# tldr ebook-polish >./tldr/ebook-polish.txt
# tldr editor >./tldr/editor.txt
# tldr env >./tldr/env.txt
# tldr eslint >./tldr/eslint.txt
# tldr exfatlabel >./tldr/exfatlabel.txt
# tldr e2image >./tldr/e2image.txt
# tldr ebook-viewer >./tldr/ebook-viewer.txt
# tldr editres >./tldr/editres.txt
# tldr envsubst >./tldr/envsubst.txt
# tldr esparse >./tldr/esparse.txt
# tldr exifautotran >./tldr/exifautotran.txt
# tldr e2label >./tldr/e2label.txt
# tldr ebtables >./tldr/ebtables.txt
# tldr eepdump >./tldr/eepdump.txt
# tldr eom >./tldr/eom.txt
# tldr espeak >./tldr/espeak.txt
# tldr exit >./tldr/exit.txt
# tldr e2mmpstatus >./tldr/e2mmpstatus.txt
# tldr ebtables-nft >./tldr/ebtables-nft.txt
# tldr eepflash.sh >./tldr/eepflash.sh.txt
# tldr eps2eps >./tldr/eps2eps.txt
# tldr espeak-ng >./tldr/espeak-ng.txt
# tldr exonpairs >./tldr/exonpairs.txt
# tldr e2scrub >./tldr/e2scrub.txt
# tldr ebtables-nft-restore >./tldr/ebtables-nft-restore.txt
# tldr eepmake >./tldr/eepmake.txt
# tldr epylint >./tldr/epylint.txt
# tldr esvalidate >./tldr/esvalidate.txt
# tldr expand >./tldr/expand.txt
# tldr e2scrub_all >./tldr/e2scrub_all.txt
# tldr ebtables-nft-save >./tldr/ebtables-nft-save.txt
# tldr egrep >./tldr/egrep.txt
# tldr eqn >./tldr/eqn.txt
# tldr ethtool >./tldr/ethtool.txt
# tldr expiry >./tldr/expiry.txt
# tldr e2undo >./tldr/e2undo.txt
# tldr ebtables-restore >./tldr/ebtables-restore.txt
# tldr eject >./tldr/eject.txt
# tldr era_check >./tldr/era_check.txt
# tldr eval >./tldr/eval.txt
# tldr export >./tldr/export.txt
# tldr e4crypt >./tldr/e4crypt.txt
# tldr ebtables-save >./tldr/ebtables-save.txt
# tldr elfedit >./tldr/elfedit.txt
# tldr era_dump >./tldr/era_dump.txt
# tldr evince >./tldr/evince.txt
# tldr expr >./tldr/expr.txt
# tldr e4defrag >./tldr/e4defrag.txt
# tldr ebtables-translate >./tldr/ebtables-translate.txt
# tldr elif >./tldr/elif.txt
# tldr era_invalidate >./tldr/era_invalidate.txt
# tldr evince-previewer >./tldr/evince-previewer.txt
# tldr ebook-convert >./tldr/ebook-convert.txt
# tldr echo >./tldr/echo.txt
# tldr else >./tldr/else.txt
# tldr era_restore >./tldr/era_restore.txt
# tldr evince-thumbnailer >./tldr/evince-thumbnailer.txt
# tldr ebook-device >./tldr/ebook-device.txt
# tldr ed >./tldr/ed.txt
# tldr enable >./tldr/enable.txt
# tldr esac >./tldr/esac.txt
# tldr ex >./tldr/ex.txt
# tldr ebook-edit >./tldr/ebook-edit.txt
# tldr edgepaint >./tldr/edgepaint.txt
# tldr enc2xs >./tldr/enc2xs.txt
# tldr escodegen >./tldr/escodegen.txt
# tldr exec >./tldr/exec.txt
# tldr f2py >./tldr/f2py.txt
# tldr fbstat >./tldr/fbstat.txt
# tldr fetch-ebook-metadata >./tldr/fetch-ebook-metadata.txt
# tldr fio_generate_plots >./tldr/fio_generate_plots.txt
# tldr fsck.exfat >./tldr/fsck.exfat.txt
# tldr f2py3 >./tldr/f2py3.txt
# tldr fbsvcmgr >./tldr/fbsvcmgr.txt
# tldr ffmpeg >./tldr/ffmpeg.txt
# tldr fio-genzipf >./tldr/fio-genzipf.txt
# tldr fsck.ext2 >./tldr/fsck.ext2.txt
# tldr f2py3.11 >./tldr/f2py3.11.txt
# tldr fbtest >./tldr/fbtest.txt
# tldr ffplay >./tldr/ffplay.txt
# tldr fio_jsonplus_clat2csv >./tldr/fio_jsonplus_clat2csv.txt
# tldr fsck.ext3 >./tldr/fsck.ext3.txt
# tldr factor >./tldr/factor.txt
# tldr fc >./tldr/fc.txt
# tldr ffprobe >./tldr/ffprobe.txt
# tldr fio-verify-state >./tldr/fio-verify-state.txt
# tldr fsck.ext4 >./tldr/fsck.ext4.txt
# tldr faillock >./tldr/faillock.txt
# tldr fc-cache >./tldr/fc-cache.txt
# tldr fg >./tldr/fg.txt
# tldr firefox >./tldr/firefox.txt
# tldr fsck.fat >./tldr/fsck.fat.txt
# tldr faillog >./tldr/faillog.txt
# tldr fc-cat >./tldr/fc-cat.txt
# tldr fgconsole >./tldr/fgconsole.txt
# tldr fixparts >./tldr/fixparts.txt
# tldr fsck.minix >./tldr/fsck.minix.txt
# tldr faked-sysv >./tldr/faked-sysv.txt
# tldr fc-conflist >./tldr/fc-conflist.txt
# tldr fgrep >./tldr/fgrep.txt
# tldr flashrom >./tldr/flashrom.txt
# tldr fsck.msdos >./tldr/fsck.msdos.txt
# tldr faked-tcp >./tldr/faked-tcp.txt
# tldr fc-list >./tldr/fc-list.txt
# tldr fi >./tldr/fi.txt
# tldr flask >./tldr/flask.txt
# tldr fsck.vfat >./tldr/fsck.vfat.txt
# tldr fake-hwclock >./tldr/fake-hwclock.txt
# tldr fc-match >./tldr/fc-match.txt
# tldr file >./tldr/file.txt
# tldr flock >./tldr/flock.txt
# tldr fsfreeze >./tldr/fsfreeze.txt
# tldr fakeroot >./tldr/fakeroot.txt
# tldr fc-pattern >./tldr/fc-pattern.txt
# tldr file2brl >./tldr/file2brl.txt
# tldr fmt >./tldr/fmt.txt
# tldr fstab-decode >./tldr/fstab-decode.txt
# tldr fakeroot-sysv >./tldr/fakeroot-sysv.txt
# tldr fc-query >./tldr/fc-query.txt
# tldr filefrag >./tldr/filefrag.txt
# tldr fold >./tldr/fold.txt
# tldr fstrim >./tldr/fstrim.txt
# tldr fakeroot-tcp >./tldr/fakeroot-tcp.txt
# tldr fc-scan >./tldr/fc-scan.txt
# tldr fincore >./tldr/fincore.txt
# tldr fonttosfnt >./tldr/fonttosfnt.txt
# tldr function >./tldr/function.txt
# tldr fallocate >./tldr/fallocate.txt
# tldr fc-validate >./tldr/fc-validate.txt
# tldr find >./tldr/find.txt
# tldr foomatic-rip >./tldr/foomatic-rip.txt
# tldr funzip >./tldr/funzip.txt
# tldr false >./tldr/false.txt
# tldr fdisk >./tldr/fdisk.txt
# tldr findfs >./tldr/findfs.txt
# tldr for >./tldr/for.txt
# tldr fuser >./tldr/fuser.txt
# tldr fathom >./tldr/fathom.txt
# tldr fdp >./tldr/fdp.txt
# tldr findmnt >./tldr/findmnt.txt
# tldr forge >./tldr/forge.txt
# tldr fusermount >./tldr/fusermount.txt
# tldr fatlabel >./tldr/fatlabel.txt
# tldr fdtdump >./tldr/fdtdump.txt
# tldr fio >./tldr/fio.txt
# tldr free >./tldr/free.txt
# tldr fusermount3 >./tldr/fusermount3.txt
# tldr fbcli >./tldr/fbcli.txt
# tldr fdtget >./tldr/fdtget.txt
# tldr fio2gnuplot >./tldr/fio2gnuplot.txt
# tldr fsadm >./tldr/fsadm.txt
# tldr fbd-theme-validate >./tldr/fbd-theme-validate.txt
# tldr fdtoverlay >./tldr/fdtoverlay.txt
# tldr fio-btrace2fio >./tldr/fio-btrace2fio.txt
# tldr fsck >./tldr/fsck.txt
# tldr fbset >./tldr/fbset.txt
# tldr fdtput >./tldr/fdtput.txt
# tldr fio-dedupe >./tldr/fio-dedupe.txt
# tldr fsck.cramfs >./tldr/fsck.cramfs.txt
# tldr g++ >./tldr/g++.txt
# tldr geany >./tldr/geany.txt
# tldr git-upload-pack >./tldr/git-upload-pack.txt
# tldr gpg-zip >./tldr/gpg-zip.txt
# tldr gslj >./tldr/gslj.txt
# tldr g++-12 >./tldr/g++-12.txt
# tldr gencat >./tldr/gencat.txt
# tldr glib-compile-schemas >./tldr/glib-compile-schemas.txt
# tldr gpic >./tldr/gpic.txt
# tldr gslp >./tldr/gslp.txt
# tldr galculator >./tldr/galculator.txt
# tldr genfio >./tldr/genfio.txt
# tldr gmake >./tldr/gmake.txt
# tldr gpiodetect >./tldr/gpiodetect.txt
# tldr gsnd >./tldr/gsnd.txt
# tldr gamma4scanimage >./tldr/gamma4scanimage.txt
# tldr genisoimage >./tldr/genisoimage.txt
# tldr gml2gv >./tldr/gml2gv.txt
# tldr gpiofind >./tldr/gpiofind.txt
# tldr gtbl >./tldr/gtbl.txt
# tldr gapplication >./tldr/gapplication.txt
# tldr genl >./tldr/genl.txt
# tldr gnome-disk-image-mounter >./tldr/gnome-disk-image-mounter.txt
# tldr gpioget >./tldr/gpioget.txt
# tldr gtf >./tldr/gtf.txt
# tldr gatttool >./tldr/gatttool.txt
# tldr geqn >./tldr/geqn.txt
# tldr gnome-disks >./tldr/gnome-disks.txt
# tldr gpioinfo >./tldr/gpioinfo.txt
# tldr gtk-nop >./tldr/gtk-nop.txt
# tldr gbak >./tldr/gbak.txt
# tldr getcap >./tldr/getcap.txt
# tldr gnome-help >./tldr/gnome-help.txt
# tldr gpiomon >./tldr/gpiomon.txt
# tldr gtk-update-icon-cache >./tldr/gtk-update-icon-cache.txt
# tldr gc >./tldr/gc.txt
# tldr getcifsacl >./tldr/getcifsacl.txt
# tldr gnome-keyring >./tldr/gnome-keyring.txt
# tldr gpioset >./tldr/gpioset.txt
# tldr gts2dxf >./tldr/gts2dxf.txt
# tldr gcc >./tldr/gcc.txt
# tldr getconf >./tldr/getconf.txt
# tldr gnome-keyring-3 >./tldr/gnome-keyring-3.txt
# tldr gpre >./tldr/gpre.txt
# tldr gts2oogl >./tldr/gts2oogl.txt
# tldr gcc-12 >./tldr/gcc-12.txt
# tldr get-edid >./tldr/get-edid.txt
# tldr gnome-keyring-daemon >./tldr/gnome-keyring-daemon.txt
# tldr gprof >./tldr/gprof.txt
# tldr gts2stl >./tldr/gts2stl.txt
# tldr gcc-ar >./tldr/gcc-ar.txt
# tldr geteltorito >./tldr/geteltorito.txt
# tldr gnome-menus-blacklist >./tldr/gnome-menus-blacklist.txt
# tldr gprofng >./tldr/gprofng.txt
# tldr gts2xyz >./tldr/gts2xyz.txt
# tldr gcc-ar-12 >./tldr/gcc-ar-12.txt
# tldr getent >./tldr/getent.txt
# tldr gnome-www-browser >./tldr/gnome-www-browser.txt
# tldr graphml2gv >./tldr/graphml2gv.txt
# tldr gtscheck >./tldr/gtscheck.txt
# tldr gcc-nm >./tldr/gcc-nm.txt
# tldr getfacl >./tldr/getfacl.txt
# tldr gnutls-cli >./tldr/gnutls-cli.txt
# tldr grep >./tldr/grep.txt
# tldr gtscompare >./tldr/gtscompare.txt
# tldr gcc-nm-12 >./tldr/gcc-nm-12.txt
# tldr getkeycodes >./tldr/getkeycodes.txt
# tldr gnutls-cli-debug >./tldr/gnutls-cli-debug.txt
# tldr gresource >./tldr/gresource.txt
# tldr gts-config >./tldr/gts-config.txt
# tldr gcc-ranlib >./tldr/gcc-ranlib.txt
# tldr get_objgraph >./tldr/get_objgraph.txt
# tldr gnutls-serv >./tldr/gnutls-serv.txt
# tldr grim >./tldr/grim.txt
# tldr gtstemplate >./tldr/gtstemplate.txt
# tldr gcc-ranlib-12 >./tldr/gcc-ranlib-12.txt
# tldr getopt >./tldr/getopt.txt
# tldr gold >./tldr/gold.txt
# tldr groff >./tldr/groff.txt
# tldr gui-pkinst >./tldr/gui-pkinst.txt
# tldr gcore >./tldr/gcore.txt
# tldr getopts >./tldr/getopts.txt
# tldr gp-archive >./tldr/gp-archive.txt
# tldr grog >./tldr/grog.txt
# tldr gui-updater >./tldr/gui-updater.txt
# tldr gcov >./tldr/gcov.txt
# tldr getpcaps >./tldr/getpcaps.txt
# tldr gparted >./tldr/gparted.txt
# tldr grops >./tldr/grops.txt
# tldr gunzip >./tldr/gunzip.txt
# tldr gcov-12 >./tldr/gcov-12.txt
# tldr gettext >./tldr/gettext.txt
# tldr gpasswd >./tldr/gpasswd.txt
# tldr grotty >./tldr/grotty.txt
# tldr gv2gml >./tldr/gv2gml.txt
# tldr gcov-dump >./tldr/gcov-dump.txt
# tldr gettext.sh >./tldr/gettext.sh.txt
# tldr gp-collect-app >./tldr/gp-collect-app.txt
# tldr groupadd >./tldr/groupadd.txt
# tldr gv2gxl >./tldr/gv2gxl.txt
# tldr gcov-dump-12 >./tldr/gcov-dump-12.txt
# tldr getty >./tldr/getty.txt
# tldr gp-display-html >./tldr/gp-display-html.txt
# tldr groupdel >./tldr/groupdel.txt
# tldr gvcolor >./tldr/gvcolor.txt
# tldr h2ph >./tldr/h2ph.txt
# tldr hdmi-audio-select >./tldr/hdmi-audio-select.txt
# tldr hostname >./tldr/hostname.txt
# tldr hp-levels >./tldr/hp-levels.txt
# tldr hp-timedate >./tldr/hp-timedate.txt
# tldr h2xs >./tldr/h2xs.txt
# tldr head >./tldr/head.txt
# tldr hostnamectl >./tldr/hostnamectl.txt
# tldr hp-logcapture >./tldr/hp-logcapture.txt
# tldr html2markdown >./tldr/html2markdown.txt
# tldr halt >./tldr/halt.txt
# tldr help >./tldr/help.txt
# tldr hp-align >./tldr/hp-align.txt
# tldr hp-makeuri >./tldr/hp-makeuri.txt
# tldr html2markdown.py3 >./tldr/html2markdown.py3.txt
# tldr handlebars >./tldr/handlebars.txt
# tldr helpztags >./tldr/helpztags.txt
# tldr hp-check >./tldr/hp-check.txt
# tldr hp-pkservice >./tldr/hp-pkservice.txt
# tldr htop >./tldr/htop.txt
# tldr hardlink >./tldr/hardlink.txt
# tldr hex2hcd >./tldr/hex2hcd.txt
# tldr hp-clean >./tldr/hp-clean.txt
# tldr hp-plugin >./tldr/hp-plugin.txt
# tldr httpx >./tldr/httpx.txt
# tldr hash >./tldr/hash.txt
# tldr hexdump >./tldr/hexdump.txt
# tldr hp-colorcal >./tldr/hp-colorcal.txt
# tldr hp-probe >./tldr/hp-probe.txt
# tldr hwclock >./tldr/hwclock.txt
# tldr hciattach >./tldr/hciattach.txt
# tldr history >./tldr/history.txt
# tldr hp-config_usb_printer >./tldr/hp-config_usb_printer.txt
# tldr hp-query >./tldr/hp-query.txt
# tldr hciconfig >./tldr/hciconfig.txt
# tldr hmm-assembler.pl >./tldr/hmm-assembler.pl.txt
# tldr hp-doctor >./tldr/hp-doctor.txt
# tldr hp-scan >./tldr/hp-scan.txt
# tldr hcitool >./tldr/hcitool.txt
# tldr hmm-info >./tldr/hmm-info.txt
# tldr hp-firmware >./tldr/hp-firmware.txt
# tldr hp-setup >./tldr/hp-setup.txt
# tldr hd >./tldr/hd.txt
# tldr hostid >./tldr/hostid.txt
# tldr hp-info >./tldr/hp-info.txt
# tldr hp-testpage >./tldr/hp-testpage.txt
# tldr i2cdetect >./tldr/i2cdetect.txt
# tldr install-sgmlcatalog >./tldr/install-sgmlcatalog.txt
# tldr ipmaddr >./tldr/ipmaddr.txt
# tldr ir-ctl >./tldr/ir-ctl.txt
# tldr i2cdump >./tldr/i2cdump.txt
# tldr instmodsh >./tldr/instmodsh.txt
# tldr ippevepcl >./tldr/ippevepcl.txt
# tldr ischroot >./tldr/ischroot.txt
# tldr i2cget >./tldr/i2cget.txt
# tldr invoke-rc.d >./tldr/invoke-rc.d.txt
# tldr ippeveprinter >./tldr/ippeveprinter.txt
# tldr isodump >./tldr/isodump.txt
# tldr i2cset >./tldr/i2cset.txt
# tldr ionice >./tldr/ionice.txt
# tldr ippeveps >./tldr/ippeveps.txt
# tldr isoinfo >./tldr/isoinfo.txt
# tldr i2c-stub-from-dump >./tldr/i2c-stub-from-dump.txt
# tldr ip >./tldr/ip.txt
# tldr ippfind >./tldr/ippfind.txt
# tldr isosize >./tldr/isosize.txt
# tldr i2ctransfer >./tldr/i2ctransfer.txt
# tldr ip6tables >./tldr/ip6tables.txt
# tldr ipptool >./tldr/ipptool.txt
# tldr isovfy >./tldr/isovfy.txt
# tldr iceauth >./tldr/iceauth.txt
# tldr ip6tables-apply >./tldr/ip6tables-apply.txt
# tldr ipp-usb >./tldr/ipp-usb.txt
# tldr ispell-autobuildhash >./tldr/ispell-autobuildhash.txt
# tldr iconv >./tldr/iconv.txt
# tldr ip6tables-legacy >./tldr/ip6tables-legacy.txt
# tldr iptables >./tldr/iptables.txt
# tldr ispell-wrapper >./tldr/ispell-wrapper.txt
# tldr iconvconfig >./tldr/iconvconfig.txt
# tldr ip6tables-legacy-restore >./tldr/ip6tables-legacy-restore.txt
# tldr iptables-apply >./tldr/iptables-apply.txt
# tldr isql-fb >./tldr/isql-fb.txt
# tldr id >./tldr/id.txt
# tldr ip6tables-legacy-save >./tldr/ip6tables-legacy-save.txt
# tldr iptables-legacy >./tldr/iptables-legacy.txt
# tldr istanbul >./tldr/istanbul.txt
# tldr iecset >./tldr/iecset.txt
# tldr ip6tables-nft >./tldr/ip6tables-nft.txt
# tldr iptables-legacy-restore >./tldr/iptables-legacy-restore.txt
# tldr isympy >./tldr/isympy.txt
# tldr if >./tldr/if.txt
# tldr ip6tables-nft-restore >./tldr/ip6tables-nft-restore.txt
# tldr iptables-legacy-save >./tldr/iptables-legacy-save.txt
# tldr isympy3 >./tldr/isympy3.txt
# tldr ifconfig >./tldr/ifconfig.txt
# tldr ip6tables-nft-save >./tldr/ip6tables-nft-save.txt
# tldr iptables-nft >./tldr/iptables-nft.txt
# tldr ivtv-ctl >./tldr/ivtv-ctl.txt
# tldr iio-sensor-proxy >./tldr/iio-sensor-proxy.txt
# tldr ip6tables-restore >./tldr/ip6tables-restore.txt
# tldr iptables-nft-restore >./tldr/iptables-nft-restore.txt
# tldr iw >./tldr/iw.txt
# tldr in >./tldr/in.txt
# tldr ip6tables-restore-translate >./tldr/ip6tables-restore-translate.txt
# tldr iptables-nft-save >./tldr/iptables-nft-save.txt
# tldr iwconfig >./tldr/iwconfig.txt
# tldr infocmp >./tldr/infocmp.txt
# tldr ip6tables-save >./tldr/ip6tables-save.txt
# tldr iptables-restore >./tldr/iptables-restore.txt
# tldr iwevent >./tldr/iwevent.txt
# tldr infotocap >./tldr/infotocap.txt
# tldr ip6tables-translate >./tldr/ip6tables-translate.txt
# tldr iptables-restore-translate >./tldr/iptables-restore-translate.txt
# tldr iwgetid >./tldr/iwgetid.txt
# tldr init >./tldr/init.txt
# tldr ipa_verify >./tldr/ipa_verify.txt
# tldr iptables-save >./tldr/iptables-save.txt
# tldr iwlist >./tldr/iwlist.txt
# tldr insmod >./tldr/insmod.txt
# tldr ipcmk >./tldr/ipcmk.txt
# tldr iptables-translate >./tldr/iptables-translate.txt
# tldr iwpriv >./tldr/iwpriv.txt
# tldr install >./tldr/install.txt
# tldr ipcrm >./tldr/ipcrm.txt
# tldr iptables-xml >./tldr/iptables-xml.txt
# tldr iwspy >./tldr/iwspy.txt
# tldr installkernel >./tldr/installkernel.txt
# tldr ipcs >./tldr/ipcs.txt
# tldr iptunnel >./tldr/iptunnel.txt
# tldr jar >./tldr/jar.txt
# tldr jcmd >./tldr/jcmd.txt
# tldr jfr >./tldr/jfr.txt
# tldr jmod >./tldr/jmod.txt
# tldr jpegtran >./tldr/jpegtran.txt
# tldr json5 >./tldr/json5.txt
# tldr jstatd >./tldr/jstatd.txt
# tldr jarsigner >./tldr/jarsigner.txt
# tldr jconsole >./tldr/jconsole.txt
# tldr jhsdb >./tldr/jhsdb.txt
# tldr jobs >./tldr/jobs.txt
# tldr jps >./tldr/jps.txt
# tldr jsonpointer >./tldr/jsonpointer.txt
# tldr js-yaml >./tldr/js-yaml.txt
# tldr java >./tldr/java.txt
# tldr jdb >./tldr/jdb.txt
# tldr jimage >./tldr/jimage.txt
# tldr join >./tldr/join.txt
# tldr jrunscript >./tldr/jrunscript.txt
# tldr json_pp >./tldr/json_pp.txt
# tldr jupyter-execute >./tldr/jupyter-execute.txt
# tldr javac >./tldr/javac.txt
# tldr jdeprscan >./tldr/jdeprscan.txt
# tldr jinfo >./tldr/jinfo.txt
# tldr journalctl >./tldr/journalctl.txt
# tldr js >./tldr/js.txt
# tldr jsonschema >./tldr/jsonschema.txt
# tldr javadoc >./tldr/javadoc.txt
# tldr jdeps >./tldr/jdeps.txt
# tldr jlink >./tldr/jlink.txt
# tldr jpackage >./tldr/jpackage.txt
# tldr jsesc >./tldr/jsesc.txt
# tldr jstack >./tldr/jstack.txt
# tldr javap >./tldr/javap.txt
# tldr jexec >./tldr/jexec.txt
# tldr jmap >./tldr/jmap.txt
# tldr jpegexiforient >./tldr/jpegexiforient.txt
# tldr jshell >./tldr/jshell.txt
# tldr jstat >./tldr/jstat.txt
# tldr kactivities-cli >./tldr/kactivities-cli.txt
# tldr kbxutil >./tldr/kbxutil.txt
# tldr keyctl >./tldr/keyctl.txt
# tldr killall >./tldr/killall.txt
# tldr kpackagelauncherqml >./tldr/kpackagelauncherqml.txt
# tldr kturtle >./tldr/kturtle.txt
# tldr kanshi >./tldr/kanshi.txt
# tldr kcookiejar5 >./tldr/kcookiejar5.txt
# tldr key.dns_resolver >./tldr/key.dns_resolver.txt
# tldr killall5 >./tldr/killall5.txt
# tldr kpackagetool5 >./tldr/kpackagetool5.txt
# tldr kvm >./tldr/kvm.txt
# tldr kbdinfo >./tldr/kbdinfo.txt
# tldr kded5 >./tldr/kded5.txt
# tldr keytool >./tldr/keytool.txt
# tldr kmod >./tldr/kmod.txt
# tldr kquitapp5 >./tldr/kquitapp5.txt
# tldr kwalletd5 >./tldr/kwalletd5.txt
# tldr kbd_mode >./tldr/kbd_mode.txt
# tldr kde-geo-uri-handler >./tldr/kde-geo-uri-handler.txt
# tldr kglobalaccel5 >./tldr/kglobalaccel5.txt
# tldr kmsblank >./tldr/kmsblank.txt
# tldr kreadconfig5 >./tldr/kreadconfig5.txt
# tldr kwallet-query >./tldr/kwallet-query.txt
# tldr kbdrate >./tldr/kbdrate.txt
# tldr kdtc >./tldr/kdtc.txt
# tldr kiconfinder5 >./tldr/kiconfinder5.txt
# tldr kmsprint >./tldr/kmsprint.txt
# tldr ktelnetservice5 >./tldr/ktelnetservice5.txt
# tldr kwriteconfig5 >./tldr/kwriteconfig5.txt
# tldr kbuildsycoca5 >./tldr/kbuildsycoca5.txt
# tldr kernel-install >./tldr/kernel-install.txt
# tldr kill >./tldr/kill.txt
# tldr kmstest >./tldr/kmstest.txt
# tldr ktrash5 >./tldr/ktrash5.txt
# tldr l2ping >./tldr/l2ping.txt
# tldr linux-version >./tldr/linux-version.txt
# tldr lpstat >./tldr/lpstat.txt
# tldr lvmdump >./tldr/lvmdump.txt
# tldr l2test >./tldr/l2test.txt
# tldr listres >./tldr/listres.txt
# tldr lrf2lrs >./tldr/lrf2lrs.txt
# tldr lvmpolld >./tldr/lvmpolld.txt
# tldr labwc >./tldr/labwc.txt
# tldr ln >./tldr/ln.txt
# tldr lrfviewer >./tldr/lrfviewer.txt
# tldr lvmsadc >./tldr/lvmsadc.txt
# tldr labwc-pi >./tldr/labwc-pi.txt
# tldr lneato >./tldr/lneato.txt
# tldr lrs2lrf >./tldr/lrs2lrf.txt
# tldr lvmsar >./tldr/lvmsar.txt
# tldr labwc-prompt >./tldr/labwc-prompt.txt
# tldr lnstat >./tldr/lnstat.txt
# tldr ls >./tldr/ls.txt
# tldr lvreduce >./tldr/lvreduce.txt
# tldr laptop-detect >./tldr/laptop-detect.txt
# tldr loadkeys >./tldr/loadkeys.txt
# tldr lsattr >./tldr/lsattr.txt
# tldr lvremove >./tldr/lvremove.txt
# tldr last >./tldr/last.txt
# tldr loadunimap >./tldr/loadunimap.txt
# tldr lsblk >./tldr/lsblk.txt
# tldr lvrename >./tldr/lvrename.txt
# tldr lastb >./tldr/lastb.txt
# tldr lobase >./tldr/lobase.txt
# tldr lsb_release >./tldr/lsb_release.txt
# tldr lvresize >./tldr/lvresize.txt
# tldr lastlog >./tldr/lastlog.txt
# tldr local >./tldr/local.txt
# tldr lscpu >./tldr/lscpu.txt
# tldr lvs >./tldr/lvs.txt
# tldr lc-compliance >./tldr/lc-compliance.txt
# tldr localc >./tldr/localc.txt
# tldr lsfd >./tldr/lsfd.txt
# tldr lvscan >./tldr/lvscan.txt
# tldr lcf >./tldr/lcf.txt
# tldr locale >./tldr/locale.txt
# tldr lsinitramfs >./tldr/lsinitramfs.txt
# tldr lwrespawn >./tldr/lwrespawn.txt
# tldr ld >./tldr/ld.txt
# tldr localectl >./tldr/localectl.txt
# tldr lsipc >./tldr/lsipc.txt
# tldr lxappearance >./tldr/lxappearance.txt
# tldr ldattach >./tldr/ldattach.txt
# tldr localedef >./tldr/localedef.txt
# tldr lsirq >./tldr/lsirq.txt
# tldr lxclipboard >./tldr/lxclipboard.txt
# tldr ld.bfd >./tldr/ld.bfd.txt
# tldr locale-gen >./tldr/locale-gen.txt
# tldr lslocks >./tldr/lslocks.txt
# tldr lxde-logout >./tldr/lxde-logout.txt
# tldr ldconfig >./tldr/ldconfig.txt
# tldr lodraw >./tldr/lodraw.txt
# tldr lslogins >./tldr/lslogins.txt
# tldr lxhotkey >./tldr/lxhotkey.txt
# tldr ldd >./tldr/ldd.txt
# tldr loffice >./tldr/loffice.txt
# tldr lsmdev >./tldr/lsmdev.txt
# tldr lxpanel >./tldr/lxpanel.txt
# tldr ld.gold >./tldr/ld.gold.txt
# tldr lofromtemplate >./tldr/lofromtemplate.txt
# tldr lsmem >./tldr/lsmem.txt
# tldr lxpanelctl >./tldr/lxpanelctl.txt
# tldr ld.so >./tldr/ld.so.txt
# tldr logger >./tldr/logger.txt
# tldr lsmod >./tldr/lsmod.txt
# tldr lxpolkit >./tldr/lxpolkit.txt
# tldr lefty >./tldr/lefty.txt
# tldr logilab-pytest >./tldr/logilab-pytest.txt
# tldr lsns >./tldr/lsns.txt
# tldr lxrandr >./tldr/lxrandr.txt
# tldr less >./tldr/less.txt
# tldr login >./tldr/login.txt
# tldr lsof >./tldr/lsof.txt
# tldr lxsession >./tldr/lxsession.txt
# tldr lessecho >./tldr/lessecho.txt
# tldr loginctl >./tldr/loginctl.txt
# tldr lspci >./tldr/lspci.txt
# tldr lxsession-db >./tldr/lxsession-db.txt
# tldr lessfile >./tldr/lessfile.txt
# tldr logname >./tldr/logname.txt
# tldr lspgpot >./tldr/lspgpot.txt
# tldr lxsession-default >./tldr/lxsession-default.txt
# tldr lesskey >./tldr/lesskey.txt
# tldr logout >./tldr/logout.txt
# tldr lsusb >./tldr/lsusb.txt
# tldr lxsession-default-terminal >./tldr/lxsession-default-terminal.txt
# tldr lesspipe >./tldr/lesspipe.txt
# tldr logrotate >./tldr/logrotate.txt
# tldr lto-dump >./tldr/lto-dump.txt
# tldr lxsession-edit >./tldr/lxsession-edit.txt
# tldr let >./tldr/let.txt
# tldr logsave >./tldr/logsave.txt
# tldr lto-dump-12 >./tldr/lto-dump-12.txt
# tldr lxsession-logout >./tldr/lxsession-logout.txt
# tldr lexgrog >./tldr/lexgrog.txt
# tldr loimpress >./tldr/loimpress.txt
# tldr lua >./tldr/lua.txt
# tldr lxsession-xdg-autostart >./tldr/lxsession-xdg-autostart.txt
# tldr libcamerify >./tldr/libcamerify.txt
# tldr lomath >./tldr/lomath.txt
# tldr lua5.1 >./tldr/lua5.1.txt
# tldr lxtask >./tldr/lxtask.txt
# tldr libgvc6-config-update >./tldr/libgvc6-config-update.txt
# tldr look >./tldr/look.txt
# tldr luac >./tldr/luac.txt
# tldr lxterminal >./tldr/lxterminal.txt
# tldr libinput >./tldr/libinput.txt
# tldr losetup >./tldr/losetup.txt
# tldr luac5.1 >./tldr/luac5.1.txt
# tldr lynx >./tldr/lynx.txt
# tldr libnetcfg >./tldr/libnetcfg.txt
# tldr loweb >./tldr/loweb.txt
# tldr luajit >./tldr/luajit.txt
# tldr lzcat >./tldr/lzcat.txt
# tldr libreoffice >./tldr/libreoffice.txt
# tldr lowntfs-3g >./tldr/lowntfs-3g.txt
# tldr luit >./tldr/luit.txt
# tldr lzcmp >./tldr/lzcmp.txt
# tldr libvirtd >./tldr/libvirtd.txt
# tldr lowriter >./tldr/lowriter.txt
# tldr lvchange >./tldr/lvchange.txt
# tldr lzdiff >./tldr/lzdiff.txt
# tldr lightdm >./tldr/lightdm.txt
# tldr lp >./tldr/lp.txt
# tldr lvconvert >./tldr/lvconvert.txt
# tldr lzegrep >./tldr/lzegrep.txt
# tldr lightdm-gtk-greeter >./tldr/lightdm-gtk-greeter.txt
# tldr lpadmin >./tldr/lpadmin.txt
# tldr lvcreate >./tldr/lvcreate.txt
# tldr lzfgrep >./tldr/lzfgrep.txt
# tldr link >./tldr/link.txt
# tldr lp-connection-editor >./tldr/lp-connection-editor.txt
# tldr lvdisplay >./tldr/lvdisplay.txt
# tldr lzgrep >./tldr/lzgrep.txt
# tldr linux32 >./tldr/linux32.txt
# tldr lpinfo >./tldr/lpinfo.txt
# tldr lvextend >./tldr/lvextend.txt
# tldr lzless >./tldr/lzless.txt
# tldr linux64 >./tldr/linux64.txt
# tldr lpmove >./tldr/lpmove.txt
# tldr lvm >./tldr/lvm.txt
# tldr lzma >./tldr/lzma.txt
# tldr linux-check-removal >./tldr/linux-check-removal.txt
# tldr lpoptions >./tldr/lpoptions.txt
# tldr lvmconfig >./tldr/lvmconfig.txt
# tldr lzmainfo >./tldr/lzmainfo.txt
# tldr linux-update-symlinks >./tldr/linux-update-symlinks.txt
# tldr lp_solve >./tldr/lp_solve.txt
# tldr lvmdiskscan >./tldr/lvmdiskscan.txt
# tldr lzmore >./tldr/lzmore.txt
# tldr mac2unix >./tldr/mac2unix.txt
# tldr mkdir >./tldr/mkdir.txt
# tldr mkzftree >./tldr/mkzftree.txt
# tldr machinectl >./tldr/machinectl.txt
# tldr mkdosfs >./tldr/mkdosfs.txt
# tldr mm2gv >./tldr/mm2gv.txt
# tldr make >./tldr/make.txt
# tldr mke2fs >./tldr/mke2fs.txt
# tldr mmcli >./tldr/mmcli.txt
# tldr make-first-existing-target >./tldr/make-first-existing-target.txt
# tldr mkfifo >./tldr/mkfifo.txt
# tldr modeline2fb >./tldr/modeline2fb.txt
# tldr make-ssl-cert >./tldr/make-ssl-cert.txt
# tldr mkfontdir >./tldr/mkfontdir.txt
# tldr modinfo >./tldr/modinfo.txt
# tldr man >./tldr/man.txt
# tldr mkfontscale >./tldr/mkfontscale.txt
# tldr modprobe >./tldr/modprobe.txt
# tldr mandb >./tldr/mandb.txt
# tldr mkfs >./tldr/mkfs.txt
# tldr monitor-sensor >./tldr/monitor-sensor.txt
# tldr manpath >./tldr/manpath.txt
# tldr mkfs.bfs >./tldr/mkfs.bfs.txt
# tldr more >./tldr/more.txt
# tldr man-recode >./tldr/man-recode.txt
# tldr mkfs.cramfs >./tldr/mkfs.cramfs.txt
# tldr mount >./tldr/mount.txt
# tldr mapfile >./tldr/mapfile.txt
# tldr mkfs.exfat >./tldr/mkfs.exfat.txt
# tldr mount.cifs >./tldr/mount.cifs.txt
# tldr mapscrn >./tldr/mapscrn.txt
# tldr mkfs.ext2 >./tldr/mkfs.ext2.txt
# tldr mount.fuse >./tldr/mount.fuse.txt
# tldr markdown-calibre >./tldr/markdown-calibre.txt
# tldr mkfs.ext3 >./tldr/mkfs.ext3.txt
# tldr mount.fuse3 >./tldr/mount.fuse3.txt
# tldr markdown-it >./tldr/markdown-it.txt
# tldr mkfs.ext4 >./tldr/mkfs.ext4.txt
# tldr mount.lowntfs-3g >./tldr/mount.lowntfs-3g.txt
# tldr markdown_py >./tldr/markdown_py.txt
# tldr mkfs.fat >./tldr/mkfs.fat.txt
# tldr mount.nfs >./tldr/mount.nfs.txt
# tldr mate-polkit >./tldr/mate-polkit.txt
# tldr mkfs.minix >./tldr/mkfs.minix.txt
# tldr mount.nfs4 >./tldr/mount.nfs4.txt
# tldr mawk >./tldr/mawk.txt
# tldr mkfs.msdos >./tldr/mkfs.msdos.txt
# tldr mount.ntfs >./tldr/mount.ntfs.txt
# tldr mbimcli >./tldr/mbimcli.txt
# tldr mkfs.ntfs >./tldr/mkfs.ntfs.txt
# tldr mount.ntfs-3g >./tldr/mount.ntfs-3g.txt
# tldr mbim-network >./tldr/mbim-network.txt
# tldr mkfs.vfat >./tldr/mkfs.vfat.txt
# tldr mountpoint >./tldr/mountpoint.txt
# tldr mcookie >./tldr/mcookie.txt
# tldr mkhomedir_helper >./tldr/mkhomedir_helper.txt
# tldr mount.smb3 >./tldr/mount.smb3.txt
# tldr md5sum >./tldr/md5sum.txt
# tldr mkinitramfs >./tldr/mkinitramfs.txt
# tldr mountstats >./tldr/mountstats.txt
# tldr md5sum.textutils >./tldr/md5sum.textutils.txt
# tldr mkisofs >./tldr/mkisofs.txt
# tldr mousepad >./tldr/mousepad.txt
# tldr mdevctl >./tldr/mdevctl.txt
# tldr mklost+found >./tldr/mklost+found.txt
# tldr mpeg2desc >./tldr/mpeg2desc.txt
# tldr media-ctl >./tldr/media-ctl.txt
# tldr mk_modmap >./tldr/mk_modmap.txt
# tldr mpris-proxy >./tldr/mpris-proxy.txt
# tldr memusage >./tldr/memusage.txt
# tldr mknod >./tldr/mknod.txt
# tldr mt >./tldr/mt.txt
# tldr memusagestat >./tldr/memusagestat.txt
# tldr mkntfs >./tldr/mkntfs.txt
# tldr mt-gnu >./tldr/mt-gnu.txt
# tldr mesa-overlay-control.py >./tldr/mesa-overlay-control.py.txt
# tldr mkswap >./tldr/mkswap.txt
# tldr mtrace >./tldr/mtrace.txt
# tldr mesg >./tldr/mesg.txt
# tldr mktemp >./tldr/mktemp.txt
# tldr mu-editor >./tldr/mu-editor.txt
# tldr meson >./tldr/meson.txt
# tldr mkvextract >./tldr/mkvextract.txt
# tldr mv >./tldr/mv.txt
# tldr migrate-pubring-from-classic-gpg >./tldr/migrate-pubring-from-classic-gpg.txt
# tldr mkvinfo >./tldr/mkvinfo.txt
# tldr mypy >./tldr/mypy.txt
# tldr mii-tool >./tldr/mii-tool.txt
# tldr mkvmerge >./tldr/mkvmerge.txt
# tldr mypyc >./tldr/mypyc.txt
# tldr mingle >./tldr/mingle.txt
# tldr mkvpropedit >./tldr/mkvpropedit.txt
# tldr namei >./tldr/namei.txt
# tldr neqn >./tldr/neqn.txt
# tldr nfsiostat >./tldr/nfsiostat.txt
# tldr nm-online >./tldr/nm-online.txt
# tldr nologin >./tldr/nologin.txt
# tldr nstat >./tldr/nstat.txt
# tldr ntfsfix >./tldr/ntfsfix.txt
# tldr ntfsusermap >./tldr/ntfsusermap.txt
# tldr nameif >./tldr/nameif.txt
# tldr netcat >./tldr/netcat.txt
# tldr nfsstat >./tldr/nfsstat.txt
# tldr nmtui >./tldr/nmtui.txt
# tldr nop >./tldr/nop.txt
# tldr ntfs-3g >./tldr/ntfs-3g.txt
# tldr ntfsinfo >./tldr/ntfsinfo.txt
# tldr ntfswipe >./tldr/ntfswipe.txt
# tldr nano >./tldr/nano.txt
# tldr netscsid >./tldr/netscsid.txt
# tldr nft >./tldr/nft.txt
# tldr nmtui-connect >./tldr/nmtui-connect.txt
# tldr normalizer >./tldr/normalizer.txt
# tldr ntfs-3g.probe >./tldr/ntfs-3g.probe.txt
# tldr ntfslabel >./tldr/ntfslabel.txt
# tldr nudatus >./tldr/nudatus.txt
# tldr nanoid >./tldr/nanoid.txt
# tldr netstat >./tldr/netstat.txt
# tldr ngettext >./tldr/ngettext.txt
# tldr nmtui-edit >./tldr/nmtui-edit.txt
# tldr notify-send >./tldr/notify-send.txt
# tldr ntfscat >./tldr/ntfscat.txt
# tldr ntfsls >./tldr/ntfsls.txt
# tldr numfmt >./tldr/numfmt.txt
# tldr nawk >./tldr/nawk.txt
# tldr networkctl >./tldr/networkctl.txt
# tldr nice >./tldr/nice.txt
# tldr nmtui-hostname >./tldr/nmtui-hostname.txt
# tldr npm >./tldr/npm.txt
# tldr ntfsclone >./tldr/ntfsclone.txt
# tldr ntfsmove >./tldr/ntfsmove.txt
# tldr nvlc >./tldr/nvlc.txt
# tldr nbackup >./tldr/nbackup.txt
# tldr newgrp >./tldr/newgrp.txt
# tldr ninja >./tldr/ninja.txt
# tldr node >./tldr/node.txt
# tldr npm-arborist >./tldr/npm-arborist.txt
# tldr ntfscluster >./tldr/ntfscluster.txt
# tldr ntfsrecover >./tldr/ntfsrecover.txt
# tldr nyc >./tldr/nyc.txt
# tldr nc >./tldr/nc.txt
# tldr newusers >./tldr/newusers.txt
# tldr nisdomainname >./tldr/nisdomainname.txt
# tldr node-coveralls >./tldr/node-coveralls.txt
# tldr nproc >./tldr/nproc.txt
# tldr ntfscmp >./tldr/ntfscmp.txt
# tldr ntfsresize >./tldr/ntfsresize.txt
# tldr ncdu >./tldr/ncdu.txt
# tldr nfnl_osf >./tldr/nfnl_osf.txt
# tldr nl >./tldr/nl.txt
# tldr node-gyp >./tldr/node-gyp.txt
# tldr npx >./tldr/npx.txt
# tldr ntfscp >./tldr/ntfscp.txt
# tldr ntfssecaudit >./tldr/ntfssecaudit.txt
# tldr nc.openbsd >./tldr/nc.openbsd.txt
# tldr nfsconf >./tldr/nfsconf.txt
# tldr nm >./tldr/nm.txt
# tldr nodejs >./tldr/nodejs.txt
# tldr nroff >./tldr/nroff.txt
# tldr ntfsdecrypt >./tldr/ntfsdecrypt.txt
# tldr ntfstruncate >./tldr/ntfstruncate.txt
# tldr neato >./tldr/neato.txt
# tldr nfsidmap >./tldr/nfsidmap.txt
# tldr nmcli >./tldr/nmcli.txt
# tldr nohup >./tldr/nohup.txt
# tldr nsenter >./tldr/nsenter.txt
# tldr ntfsfallocate >./tldr/ntfsfallocate.txt
# tldr ntfsundelete >./tldr/ntfsundelete.txt
# tldr obamenu >./tldr/obamenu.txt
# tldr objdump >./tldr/objdump.txt
# tldr open >./tldr/open.txt
# tldr openbox-session >./tldr/openbox-session.txt
# tldr openvt >./tldr/openvt.txt
# tldr otpset >./tldr/otpset.txt
# tldr obconf >./tldr/obconf.txt
# tldr obxprop >./tldr/obxprop.txt
# tldr openbox >./tldr/openbox.txt
# tldr opener >./tldr/opener.txt
# tldr optipng >./tldr/optipng.txt
# tldr overlaycheck >./tldr/overlaycheck.txt
# tldr obexctl >./tldr/obexctl.txt
# tldr ocsptool >./tldr/ocsptool.txt
# tldr openbox-lxde >./tldr/openbox-lxde.txt
# tldr openocd >./tldr/openocd.txt
# tldr osage >./tldr/osage.txt
# tldr ovmerge >./tldr/ovmerge.txt
# tldr objcopy >./tldr/objcopy.txt
# tldr od >./tldr/od.txt
# tldr openbox-lxde-pi >./tldr/openbox-lxde-pi.txt
# tldr openssl >./tldr/openssl.txt
# tldr osirrox >./tldr/osirrox.txt
# tldr p11-kit >./tldr/p11-kit.txt
# tldr perlthanks >./tldr/perlthanks.txt
# tldr pod2man >./tldr/pod2man.txt
# tldr pvresize >./tldr/pvresize.txt
# tldr p11tool >./tldr/p11tool.txt
# tldr pf2afm >./tldr/pf2afm.txt
# tldr pod2text >./tldr/pod2text.txt
# tldr pvs >./tldr/pvs.txt
# tldr p7zip >./tldr/p7zip.txt
# tldr pfbtopfa >./tldr/pfbtopfa.txt
# tldr pod2usage >./tldr/pod2usage.txt
# tldr pvscan >./tldr/pvscan.txt
# tldr pacat >./tldr/pacat.txt
# tldr pgrep >./tldr/pgrep.txt
# tldr podchecker >./tldr/podchecker.txt
# tldr pw-cat >./tldr/pw-cat.txt
# tldr pacmd >./tldr/pacmd.txt
# tldr pgzrun >./tldr/pgzrun.txt
# tldr poff >./tldr/poff.txt
# tldr pwck >./tldr/pwck.txt
# tldr pacote >./tldr/pacote.txt
# tldr pic >./tldr/pic.txt
# tldr pon >./tldr/pon.txt
# tldr pw-cli >./tldr/pw-cli.txt
# tldr pactl >./tldr/pactl.txt
# tldr piclone >./tldr/piclone.txt
# tldr popd >./tldr/popd.txt
# tldr pw-config >./tldr/pw-config.txt
# tldr padsp >./tldr/padsp.txt
# tldr pico >./tldr/pico.txt
# tldr portablectl >./tldr/portablectl.txt
# tldr pw-container >./tldr/pw-container.txt
# tldr pager >./tldr/pager.txt
# tldr piconv >./tldr/piconv.txt
# tldr poweroff >./tldr/poweroff.txt
# tldr pwconv >./tldr/pwconv.txt
# tldr pa-info >./tldr/pa-info.txt
# tldr pidof >./tldr/pidof.txt
# tldr ppdc >./tldr/ppdc.txt
# tldr pwd >./tldr/pwd.txt
# tldr pam-auth-update >./tldr/pam-auth-update.txt
# tldr pidwait >./tldr/pidwait.txt
# tldr ppdhtml >./tldr/ppdhtml.txt
# tldr pw-dot >./tldr/pw-dot.txt
# tldr pam_getenv >./tldr/pam_getenv.txt
# tldr pig2vcd >./tldr/pig2vcd.txt
# tldr ppdi >./tldr/ppdi.txt
# tldr pw-dsdplay >./tldr/pw-dsdplay.txt
# tldr pam_namespace_helper >./tldr/pam_namespace_helper.txt
# tldr pigpiod >./tldr/pigpiod.txt
# tldr ppdmerge >./tldr/ppdmerge.txt
# tldr pw-dump >./tldr/pw-dump.txt
# tldr pamon >./tldr/pamon.txt
# tldr pi-gpk-dbus-service >./tldr/pi-gpk-dbus-service.txt
# tldr ppdpo >./tldr/ppdpo.txt
# tldr pwdx >./tldr/pwdx.txt
# tldr pam_timestamp_check >./tldr/pam_timestamp_check.txt
# tldr pi-gpk-install-local-file >./tldr/pi-gpk-install-local-file.txt
# tldr pphs >./tldr/pphs.txt
# tldr pw-encplay >./tldr/pw-encplay.txt
# tldr pandoc >./tldr/pandoc.txt
# tldr pi-gpk-log >./tldr/pi-gpk-log.txt
# tldr pppdump >./tldr/pppdump.txt
# tldr pwhistory_helper >./tldr/pwhistory_helper.txt
# tldr paperconf >./tldr/paperconf.txt
# tldr pi-gpk-prefs >./tldr/pi-gpk-prefs.txt
# tldr pppoe-discovery >./tldr/pppoe-discovery.txt
# tldr pw-link >./tldr/pw-link.txt
# tldr paperconfig >./tldr/paperconfig.txt
# tldr pi-gpk-update-viewer >./tldr/pi-gpk-update-viewer.txt
# tldr pppstats >./tldr/pppstats.txt
# tldr pw-loopback >./tldr/pw-loopback.txt
# tldr paplay >./tldr/paplay.txt
# tldr pi-greeter >./tldr/pi-greeter.txt
# tldr pprompt.sh >./tldr/pprompt.sh.txt
# tldr pw-metadata >./tldr/pw-metadata.txt
# tldr parec >./tldr/parec.txt
# tldr pigs >./tldr/pigs.txt
# tldr pr >./tldr/pr.txt
# tldr pw-mididump >./tldr/pw-mididump.txt
# tldr parecord >./tldr/parecord.txt
# tldr pinctrl >./tldr/pinctrl.txt
# tldr preconv >./tldr/preconv.txt
# tldr pw-midiplay >./tldr/pw-midiplay.txt
# tldr parse-edid >./tldr/parse-edid.txt
# tldr pinentry >./tldr/pinentry.txt
# tldr preparetips5 >./tldr/preparetips5.txt
# ...
# tldr stty >./tldr/stty.txt
# tldr systemd-nspawn >./tldr/systemd-nspawn.txt
# tldr setcap >./tldr/setcap.txt
# tldr soelim >./tldr/soelim.txt
# tldr stubgen >./tldr/stubgen.txt
# tldr systemd-path >./tldr/systemd-path.txt
# tldr setcifsacl >./tldr/setcifsacl.txt
# tldr soffice >./tldr/soffice.txt
# tldr stubtest >./tldr/stubtest.txt
# tldr systemd-repart >./tldr/systemd-repart.txt
# tldr setfacl >./tldr/setfacl.txt
# tldr sort >./tldr/sort.txt
# tldr su >./tldr/su.txt
# tldr systemd-run >./tldr/systemd-run.txt
# tldr setfont >./tldr/setfont.txt
# tldr sotruss >./tldr/sotruss.txt
# tldr sudo >./tldr/sudo.txt
# tldr systemd-socket-activate >./tldr/systemd-socket-activate.txt
# tldr setkeycodes >./tldr/setkeycodes.txt
# tldr source >./tldr/source.txt
# tldr sudoedit >./tldr/sudoedit.txt
# tldr systemd-stdio-bridge >./tldr/systemd-stdio-bridge.txt
# tldr setleds >./tldr/setleds.txt
# tldr spa-acp-tool >./tldr/spa-acp-tool.txt
# tldr sudo_logsrvd >./tldr/sudo_logsrvd.txt
# tldr systemd-sysext >./tldr/systemd-sysext.txt
# tldr setlogcons >./tldr/setlogcons.txt
# tldr spa-inspect >./tldr/spa-inspect.txt
# tldr sudopwd >./tldr/sudopwd.txt
# tldr systemd-sysusers >./tldr/systemd-sysusers.txt
# tldr setmetamode >./tldr/setmetamode.txt
# tldr spa-json-dump >./tldr/spa-json-dump.txt
# tldr sudoreplay >./tldr/sudoreplay.txt
# tldr systemd-tmpfiles >./tldr/systemd-tmpfiles.txt
# tldr setpci >./tldr/setpci.txt
# tldr spa-monitor >./tldr/spa-monitor.txt
# tldr sudo_sendlog >./tldr/sudo_sendlog.txt
# tldr systemd-tty-ask-password-agent >./tldr/systemd-tty-ask-password-agent.txt
# tldr setpriv >./tldr/setpriv.txt
# tldr spa-resample >./tldr/spa-resample.txt
# tldr sulogin >./tldr/sulogin.txt
# tldr systemd-umount >./tldr/systemd-umount.txt
# tldr setsid >./tldr/setsid.txt
# tldr spd-conf >./tldr/spd-conf.txt
# tldr sum >./tldr/sum.txt
# tldr systemsettings >./tldr/systemsettings.txt
# tldr setterm >./tldr/setterm.txt
# tldr speaker-test >./tldr/speaker-test.txt
# tldr suspend >./tldr/suspend.txt
# tldr systemsettings5 >./tldr/systemsettings5.txt
# tldr setupcon >./tldr/setupcon.txt
# tldr speak-ng >./tldr/speak-ng.txt
# tldr svgpp >./tldr/svgpp.txt
# tldr setup_env >./tldr/setup_env.txt
# tldr splain >./tldr/splain.txt
# tldr svlc >./tldr/svlc.txt
# tldr setvesablank >./tldr/setvesablank.txt
# tldr split >./tldr/split.txt
# tldr swaplabel >./tldr/swaplabel.txt
# tldr tabs >./tldr/tabs.txt
# tldr tc >./tldr/tc.txt
# tldr thin_ls >./tldr/thin_ls.txt
# tldr tipc >./tldr/tipc.txt
# tldr tr >./tldr/tr.txt
# tldr ttf2svg >./tldr/ttf2svg.txt
# tldr tac >./tldr/tac.txt
# tldr tee >./tldr/tee.txt
# tldr thin_metadata_size >./tldr/thin_metadata_size.txt
# tldr tjbench >./tldr/tjbench.txt
# tldr transform >./tldr/transform.txt
# tldr tty >./tldr/tty.txt
# tldr tail >./tldr/tail.txt
# tldr telinit >./tldr/telinit.txt
# tldr thin_repair >./tldr/thin_repair.txt
# tldr tldr >./tldr/tldr.txt
# tldr transmission-gtk >./tldr/transmission-gtk.txt
# tldr tune2fs >./tldr/tune2fs.txt
# tldr tap >./tldr/tap.txt
# tldr tempfile >./tldr/tempfile.txt
# tldr thin_restore >./tldr/thin_restore.txt
# tldr tldr-hs >./tldr/tldr-hs.txt
# tldr trap >./tldr/trap.txt
# tldr tune.exfat >./tldr/tune.exfat.txt
# tldr tape >./tldr/tape.txt
# tldr terser >./tldr/terser.txt
# tldr thin_rmap >./tldr/thin_rmap.txt
# tldr tload >./tldr/tload.txt
# tldr tred >./tldr/tred.txt
# tldr twopi >./tldr/twopi.txt
# tldr tap-mocha-reporter >./tldr/tap-mocha-reporter.txt
# tldr test >./tldr/test.txt
# tldr thin_trim >./tldr/thin_trim.txt
# tldr toc2cddb >./tldr/toc2cddb.txt
# tldr tree >./tldr/tree.txt
# tldr type >./tldr/type.txt
# tldr tap-parser >./tldr/tap-parser.txt
# tldr th-cmd >./tldr/th-cmd.txt
# tldr thonny >./tldr/thonny.txt
# tldr toc2cue >./tldr/toc2cue.txt
# tldr troff >./tldr/troff.txt
# tldr typeset >./tldr/typeset.txt
# tldr tar >./tldr/tar.txt
# tldr thd >./tldr/thd.txt
# tldr tic >./tldr/tic.txt
# tldr toe >./tldr/toe.txt
# tldr true >./tldr/true.txt
# tldr tzselect >./tldr/tzselect.txt
# tldr tarcat >./tldr/tarcat.txt
# tldr then >./tldr/then.txt
# tldr time >./tldr/time.txt
# tldr top >./tldr/top.txt
# tldr truncate >./tldr/truncate.txt
# tldr tasksel >./tldr/tasksel.txt
# tldr thin_check >./tldr/thin_check.txt
# tldr timedatectl >./tldr/timedatectl.txt
# tldr touch >./tldr/touch.txt
# tldr trust >./tldr/trust.txt
# tldr taskset >./tldr/taskset.txt
# tldr thin_delta >./tldr/thin_delta.txt
# tldr timeout >./tldr/timeout.txt
# tldr tput >./tldr/tput.txt
# tldr tset >./tldr/tset.txt
# tldr tbl >./tldr/tbl.txt
# tldr thin_dump >./tldr/thin_dump.txt
# tldr times >./tldr/times.txt
# tldr tqdm >./tldr/tqdm.txt
# tldr tsort >./tldr/tsort.txt
# tldr ucf >./tldr/ucf.txt
# tldr unexpand >./tldr/unexpand.txt
# tldr update-alternatives >./tldr/update-alternatives.txt
# tldr update-mime-database >./tldr/update-mime-database.txt
# tldr ucfq >./tldr/ucfq.txt
# tldr unflatten >./tldr/unflatten.txt
# tldr update-ca-certificates >./tldr/update-ca-certificates.txt
# tldr update-passwd >./tldr/update-passwd.txt
# tldr ucfr >./tldr/ucfr.txt
# tldr unicode_start >./tldr/unicode_start.txt
# tldr update-catalog >./tldr/update-catalog.txt
# tldr update-pciids >./tldr/update-pciids.txt
# tldr uclampset >./tldr/uclampset.txt
# tldr unicode_stop >./tldr/unicode_stop.txt
# tldr update-cracklib >./tldr/update-cracklib.txt
# tldr update-rc.d >./tldr/update-rc.d.txt
# tldr ucs2any >./tldr/ucs2any.txt
# tldr uniq >./tldr/uniq.txt
# tldr update-default-aspell >./tldr/update-default-aspell.txt
# tldr update-shells >./tldr/update-shells.txt
# tldr udevadm >./tldr/udevadm.txt
# tldr unix2dos >./tldr/unix2dos.txt
# tldr update-default-ispell >./tldr/update-default-ispell.txt
# tldr update-xmlcatalog >./tldr/update-xmlcatalog.txt
# tldr udisksctl >./tldr/udisksctl.txt
# tldr unix2mac >./tldr/unix2mac.txt
# tldr update-default-wordlist >./tldr/update-default-wordlist.txt
# tldr upower >./tldr/upower.txt
# tldr uflash >./tldr/uflash.txt
# tldr unix_chkpwd >./tldr/unix_chkpwd.txt
# tldr update-desktop-database >./tldr/update-desktop-database.txt
# tldr uptime >./tldr/uptime.txt
# tldr ul >./tldr/ul.txt
# tldr unix_update >./tldr/unix_update.txt
# tldr update-dictcommon-aspell >./tldr/update-dictcommon-aspell.txt
# tldr usb-devices >./tldr/usb-devices.txt
# tldr ulimit >./tldr/ulimit.txt
# tldr unlink >./tldr/unlink.txt
# tldr update-dictcommon-hunspell >./tldr/update-dictcommon-hunspell.txt
# tldr usbhid-dump >./tldr/usbhid-dump.txt
# tldr umask >./tldr/umask.txt
# tldr unlzma >./tldr/unlzma.txt
# tldr update-fonts-alias >./tldr/update-fonts-alias.txt
# tldr usb_modeswitch >./tldr/usb_modeswitch.txt
# tldr umax_pp >./tldr/umax_pp.txt
# tldr unmkinitramfs >./tldr/unmkinitramfs.txt
# tldr update-fonts-dir >./tldr/update-fonts-dir.txt
# tldr usb_modeswitch_dispatcher >./tldr/usb_modeswitch_dispatcher.txt
# tldr umount >./tldr/umount.txt
# tldr unopkg >./tldr/unopkg.txt
# tldr update-fonts-scale >./tldr/update-fonts-scale.txt
# tldr usbreset >./tldr/usbreset.txt
# tldr umount.nfs >./tldr/umount.nfs.txt
# tldr unset >./tldr/unset.txt
# tldr update-gsfontmap >./tldr/update-gsfontmap.txt
# tldr useradd >./tldr/useradd.txt
# tldr umount.nfs4 >./tldr/umount.nfs4.txt
# tldr unshare >./tldr/unshare.txt
# tldr update-icon-caches >./tldr/update-icon-caches.txt
# tldr userdel >./tldr/userdel.txt
# tldr umount.udisks2 >./tldr/umount.udisks2.txt
# tldr until >./tldr/until.txt
# tldr update-inetd >./tldr/update-inetd.txt
# tldr usermod >./tldr/usermod.txt
# tldr unalias >./tldr/unalias.txt
# tldr unxz >./tldr/unxz.txt
# tldr update-initramfs >./tldr/update-initramfs.txt
# tldr users >./tldr/users.txt
# tldr uname >./tldr/uname.txt
# tldr unzip >./tldr/unzip.txt
# tldr update-java-alternatives >./tldr/update-java-alternatives.txt
# tldr utmpdump >./tldr/utmpdump.txt
# tldr uncompress >./tldr/uncompress.txt
# tldr unzipsfx >./tldr/unzipsfx.txt
# tldr update-locale >./tldr/update-locale.txt
# tldr uuid >./tldr/uuid.txt
# tldr undill >./tldr/undill.txt
# tldr unzstd >./tldr/unzstd.txt
# tldr update-mime >./tldr/update-mime.txt
# tldr v4l2-compliance >./tldr/v4l2-compliance.txt
# tldr vgcreate >./tldr/vgcreate.txt
# tldr viewres >./tldr/viewres.txt
# tldr virt-ssh-helper >./tldr/virt-ssh-helper.txt
# tldr vnclicense >./tldr/vnclicense.txt
# tldr v4l2-ctl >./tldr/v4l2-ctl.txt
# tldr vgdisplay >./tldr/vgdisplay.txt
# tldr vigr >./tldr/vigr.txt
# tldr virtualenv >./tldr/virtualenv.txt
# tldr vnclicensewiz >./tldr/vnclicensewiz.txt
# tldr v4l2-dbg >./tldr/v4l2-dbg.txt
# tldr vgexport >./tldr/vgexport.txt
# tldr vimdot >./tldr/vimdot.txt
# tldr virtualenv-clone >./tldr/virtualenv-clone.txt
# tldr vncpamhelper >./tldr/vncpamhelper.txt
# tldr v4l2-sysfs-path >./tldr/v4l2-sysfs-path.txt
# tldr vgextend >./tldr/vgextend.txt
# tldr vim.tiny >./tldr/vim.tiny.txt
# tldr virt-viewer >./tldr/virt-viewer.txt
# tldr vncpasswd >./tldr/vncpasswd.txt
# tldr validlocale >./tldr/validlocale.txt
# tldr vgimport >./tldr/vgimport.txt
# tldr vipw >./tldr/vipw.txt
# tldr virt-xml >./tldr/virt-xml.txt
# tldr vncserver >./tldr/vncserver.txt
# tldr vcgencmd >./tldr/vcgencmd.txt
# tldr vgimportclone >./tldr/vgimportclone.txt
# tldr virsh >./tldr/virsh.txt
# tldr virt-xml-validate >./tldr/virt-xml-validate.txt
# tldr vncserverui >./tldr/vncserverui.txt
# tldr vclog >./tldr/vclog.txt
# tldr vgmerge >./tldr/vgmerge.txt
# tldr virt-admin >./tldr/virt-admin.txt
# tldr visudo >./tldr/visudo.txt
# tldr vncserver-virtual >./tldr/vncserver-virtual.txt
# tldr vcmailbox >./tldr/vcmailbox.txt
# tldr vgmknodes >./tldr/vgmknodes.txt
# tldr virt-clone >./tldr/virt-clone.txt
# tldr vkcube >./tldr/vkcube.txt
# tldr vncserver-virtuald >./tldr/vncserver-virtuald.txt
# tldr vcstime >./tldr/vcstime.txt
# tldr vgreduce >./tldr/vgreduce.txt
# tldr virt-host-validate >./tldr/virt-host-validate.txt
# tldr vkcubepp >./tldr/vkcubepp.txt
# tldr vncserver-x11 >./tldr/vncserver-x11.txt
# tldr vdir >./tldr/vdir.txt
# tldr vgremove >./tldr/vgremove.txt
# tldr virt-install >./tldr/virt-install.txt
# tldr vkcube-wayland >./tldr/vkcube-wayland.txt
# tldr vncserver-x11-core >./tldr/vncserver-x11-core.txt
# tldr vdpa >./tldr/vdpa.txt
# tldr vgrename >./tldr/vgrename.txt
# tldr virtlockd >./tldr/virtlockd.txt
# tldr vlc >./tldr/vlc.txt
# tldr vncserver-x11-serviced >./tldr/vncserver-x11-serviced.txt
# tldr vgcfgbackup >./tldr/vgcfgbackup.txt
# tldr vgs >./tldr/vgs.txt
# tldr virtlogd >./tldr/virtlogd.txt
# tldr vlc-wrapper >./tldr/vlc-wrapper.txt
# tldr vncviewer >./tldr/vncviewer.txt
# tldr vgcfgrestore >./tldr/vgcfgrestore.txt
# tldr vgscan >./tldr/vgscan.txt
# tldr virt-manager >./tldr/virt-manager.txt
# tldr vmstat >./tldr/vmstat.txt
# tldr vulkaninfo >./tldr/vulkaninfo.txt
# tldr vgchange >./tldr/vgchange.txt
# tldr vgsplit >./tldr/vgsplit.txt
# tldr virt-pki-query-dn >./tldr/virt-pki-query-dn.txt
# tldr vncagent >./tldr/vncagent.txt
# tldr vgck >./tldr/vgck.txt
# tldr vi >./tldr/vi.txt
# tldr virt-pki-validate >./tldr/virt-pki-validate.txt
# tldr vncfopshelper >./tldr/vncfopshelper.txt
# tldr vgconvert >./tldr/vgconvert.txt
# tldr view >./tldr/view.txt
# tldr virt-qemu-run >./tldr/virt-qemu-run.txt
# tldr vncinitconfig >./tldr/vncinitconfig.txt
# tldr w >./tldr/w.txt
# tldr wayvncctl >./tldr/wayvncctl.txt
# tldr wfrespawn >./tldr/wfrespawn.txt
# tldr whoami >./tldr/whoami.txt
# tldr wpa_supplicant >./tldr/wpa_supplicant.txt
# tldr wait >./tldr/wait.txt
# tldr wayvnc-generate-keys.sh >./tldr/wayvnc-generate-keys.sh.txt
# tldr wget >./tldr/wget.txt
# tldr wipefs >./tldr/wipefs.txt
# tldr wpctl >./tldr/wpctl.txt
# tldr wall >./tldr/wall.txt
# tldr wayvnc-run.sh >./tldr/wayvnc-run.sh.txt
# tldr whatis >./tldr/whatis.txt
# tldr wireplumber >./tldr/wireplumber.txt
# tldr wpexec >./tldr/wpexec.txt
# tldr watch >./tldr/watch.txt
# tldr wc >./tldr/wc.txt
# tldr whereis >./tldr/whereis.txt
# tldr wlopm >./tldr/wlopm.txt
# tldr write >./tldr/write.txt
# tldr watchgnupg >./tldr/watchgnupg.txt
# tldr wdctl >./tldr/wdctl.txt
# tldr which >./tldr/which.txt
# tldr wlr-randr >./tldr/wlr-randr.txt
# tldr wrjpgcom >./tldr/wrjpgcom.txt
# tldr wayfire >./tldr/wayfire.txt
# tldr web2disk >./tldr/web2disk.txt
# tldr which.debianutils >./tldr/which.debianutils.txt
# tldr wodim >./tldr/wodim.txt
# tldr wscat >./tldr/wscat.txt
# tldr wayfire-pi >./tldr/wayfire-pi.txt
# tldr webpack >./tldr/webpack.txt
# tldr while >./tldr/while.txt
# tldr wpa_action >./tldr/wpa_action.txt
# tldr wsdump >./tldr/wsdump.txt
# tldr wayvnc >./tldr/wayvnc.txt
# tldr wfpanelctl >./tldr/wfpanelctl.txt
# tldr whiptail >./tldr/whiptail.txt
# tldr wpa_cli >./tldr/wpa_cli.txt
# tldr www-browser >./tldr/www-browser.txt
# tldr wayvnc-control.py >./tldr/wayvnc-control.py.txt
# tldr wf-panel-pi >./tldr/wf-panel-pi.txt
# tldr who >./tldr/who.txt
# tldr wpa_passphrase >./tldr/wpa_passphrase.txt
# tldr xarchiver >./tldr/xarchiver.txt
# tldr xdg-settings >./tldr/xdg-settings.txt
# tldr xkbbell >./tldr/xkbbell.txt
# tldr xmllint >./tldr/xmllint.txt
# tldr xsetmode >./tldr/xsetmode.txt
# tldr x-window-manager >./tldr/x-window-manager.txt
# tldr xargs >./tldr/xargs.txt
# tldr xdg-user-dir >./tldr/xdg-user-dir.txt
# tldr xkbcomp >./tldr/xkbcomp.txt
# tldr xmlstarlet >./tldr/xmlstarlet.txt
# tldr xsetpointer >./tldr/xsetpointer.txt
# tldr xwininfo >./tldr/xwininfo.txt
# tldr xauth >./tldr/xauth.txt
# tldr xdg-user-dirs-update >./tldr/xdg-user-dirs-update.txt
# tldr xkbevd >./tldr/xkbevd.txt
# tldr xmodmap >./tldr/xmodmap.txt
# tldr xsetroot >./tldr/xsetroot.txt
# tldr x-www-browser >./tldr/x-www-browser.txt
# tldr xcmsdb >./tldr/xcmsdb.txt
# tldr xdpyinfo >./tldr/xdpyinfo.txt
# tldr xkbprint >./tldr/xkbprint.txt
# tldr xorrecord >./tldr/xorrecord.txt
# tldr xsettingsd >./tldr/xsettingsd.txt
# tldr xz >./tldr/xz.txt
# tldr xcompmgr >./tldr/xcompmgr.txt
# tldr xdriinfo >./tldr/xdriinfo.txt
# tldr xkbvleds >./tldr/xkbvleds.txt
# tldr xorriso >./tldr/xorriso.txt
# tldr xstdcmap >./tldr/xstdcmap.txt
# tldr xzcat >./tldr/xzcat.txt
# tldr xdg-dbus-proxy >./tldr/xdg-dbus-proxy.txt
# tldr xev >./tldr/xev.txt
# tldr xkbwatch >./tldr/xkbwatch.txt
# tldr xorrisofs >./tldr/xorrisofs.txt
# tldr xsubpp >./tldr/xsubpp.txt
# tldr xzcmp >./tldr/xzcmp.txt
# tldr xdg-desktop-icon >./tldr/xdg-desktop-icon.txt
# tldr xfallback.sh >./tldr/xfallback.sh.txt
# tldr xkeystone >./tldr/xkeystone.txt
# tldr xprop >./tldr/xprop.txt
# tldr xtables-legacy-multi >./tldr/xtables-legacy-multi.txt
# tldr xzdiff >./tldr/xzdiff.txt
# tldr xdg-desktop-menu >./tldr/xdg-desktop-menu.txt
# tldr xfd >./tldr/xfd.txt
# tldr xkill >./tldr/xkill.txt
# tldr xrandr >./tldr/xrandr.txt
# tldr xtables-monitor >./tldr/xtables-monitor.txt
# tldr xzegrep >./tldr/xzegrep.txt
# tldr xdg-email >./tldr/xdg-email.txt
# tldr xfontsel >./tldr/xfontsel.txt
# tldr xlsatoms >./tldr/xlsatoms.txt
# tldr xrdb >./tldr/xrdb.txt
# tldr xtables-nft-multi >./tldr/xtables-nft-multi.txt
# tldr xzfgrep >./tldr/xzfgrep.txt
# tldr xdg-icon-resource >./tldr/xdg-icon-resource.txt
# tldr xgamma >./tldr/xgamma.txt
# tldr xlsclients >./tldr/xlsclients.txt
# tldr xrefresh >./tldr/xrefresh.txt
# tldr x-terminal-emulator >./tldr/x-terminal-emulator.txt
# tldr xzgrep >./tldr/xzgrep.txt
# tldr xdg-mime >./tldr/xdg-mime.txt
# tldr xhost >./tldr/xhost.txt
# tldr xlsfonts >./tldr/xlsfonts.txt
# tldr xsel >./tldr/xsel.txt
# tldr xvidtune >./tldr/xvidtune.txt
# tldr xzless >./tldr/xzless.txt
# tldr xdg-open >./tldr/xdg-open.txt
# tldr xinit >./tldr/xinit.txt
# tldr xmessage >./tldr/xmessage.txt
# tldr x-session-manager >./tldr/x-session-manager.txt
# tldr xvinfo >./tldr/xvinfo.txt
# tldr xzmore >./tldr/xzmore.txt
# tldr xdg-screensaver >./tldr/xdg-screensaver.txt
# tldr xinput >./tldr/xinput.txt
# tldr xmlcatalog >./tldr/xmlcatalog.txt
# tldr xset >./tldr/xset.txt
# tldr xwayland-xauth >./tldr/xwayland-xauth.txt
# tldr yelp >./tldr/yelp.txt
# tldr yes >./tldr/yes.txt
# tldr ypdomainname >./tldr/ypdomainname.txt
# tldr zcat >./tldr/zcat.txt
# tldr zdump >./tldr/zdump.txt
# tldr zenoty >./tldr/zenoty.txt
# tldr zforce >./tldr/zforce.txt
# tldr zip >./tldr/zip.txt
# tldr zipgrep >./tldr/zipgrep.txt
# tldr zipsplit >./tldr/zipsplit.txt
# tldr znew >./tldr/znew.txt
# tldr zstd >./tldr/zstd.txt
# tldr zstdless >./tldr/zstdless.txt
# tldr zcmp >./tldr/zcmp.txt
# tldr zegrep >./tldr/zegrep.txt
# tldr zff2gff3.pl >./tldr/zff2gff3.pl.txt
# tldr zgrep >./tldr/zgrep.txt
# tldr zipcloak >./tldr/zipcloak.txt
# tldr zipinfo >./tldr/zipinfo.txt
# tldr zless >./tldr/zless.txt
# tldr zoe-loop >./tldr/zoe-loop.txt
# tldr zstdcat >./tldr/zstdcat.txt
# tldr zstdmt >./tldr/zstdmt.txt
# tldr zdiff >./tldr/zdiff.txt
# tldr zenity >./tldr/zenity.txt
# tldr zfgrep >./tldr/zfgrep.txt
# tldr zic >./tldr/zic.txt
# tldr zipdetails >./tldr/zipdetails.txt
# tldr zipnote >./tldr/zipnote.txt
# tldr zmore >./tldr/zmore.txt
# tldr zramctl >./tldr/zramctl.txt
# tldr zstdgrep >./tldr/zstdgrep.txt
# man Done
