# %% [markdown]
# ---
# ---
# ---
#
# # AI.ipynb

# %% [markdown]
# ---
#
# #  /home/me/Notebooks/AI

# %%
# !cd /home/me/Notebooks
# !ls /home/me/Notebooks/AI/skills
# Out:
# create_links  Skills-and-Agents-resources.txt  skills-main	skills.md
# list-skills   Skills-and-Agents.txt	       skills-main.zip

# %% [markdown]
# ---
#
# # SKILLS

# %%
# !ls AI/skills/skills-main/skills
# Out:
# algorithmic-art   docx		   pdf-work	      webapp-testing
# brand-guidelines  frontend-design  pptx		      web-artifacts-builder
# canvas-design	  internal-comms   skill-creator      xlsx
# claude-api	  mcp-builder	   slack-gif-creator
# doc-coauthoring   pdf		   theme-factory

# %% [markdown]
# ---
#
# # SCRATCH PAD

# %% [raw]
# print("")
# create a script to

# %% [markdown]
# ---
#
# # /home/me/Notebooks/.github

# %%
#!ls /home/me/Notebooks/.github/
# !ls /home/me/Notebooks/.github/instructions/
# !ls /home/me/Notebooks/.github/prompts/
# Out:
# copilot.instructions.md        pdf.instructions.md
# create.instructions.md	       startup-environment.instructions.md
# notebook-json.instructions.md
# name.prompt.md

# %% [markdown]
# ---
