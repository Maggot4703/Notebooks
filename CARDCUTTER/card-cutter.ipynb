# %% [markdown]
# ---
# ---
# ---
#
# # CARDCUTTER

# %% [markdown]
# ---
#
# ## /home/me/Notebooks/CARDCUTTER/CardCutter

# %%
# !ls /home/me/Notebooks/CARDCUTTER/CardCutter
# Out:
# AADA.csv		   card-cutter.txt  Cars4.png  Crew.csv  old
# AADA.xls		   Cars1.png	    Cars5.png  Crew.ods  __pycache__
# CardCutter.code-workspace  Cars2.png	    Cars6.png  gimp	 README.md
# card_cutter.py		   Cars3.png	    Cars7.png  LICENSE

# %% [markdown]
# ---
#
# ## RENAME ME

# %% [markdown]
# The provided Bash script, links-create.sh, is designed to search for Jupyter notebook files (`*.ipynb`) within a specific directory structure and output their paths to a file named links-ipynb.sh. The script begins by ensuring it is running under Bash, restarting itself with Bash if necessary. It then sets strict error handling options (`set -euo pipefail`) to make the script robust against common scripting errors.
#
# The script defines the search root as the current working directory and prepares an output file path. It initializes two arrays: one to store the paths of found notebooks and another (an associative array) to count occurrences of notebook basenames, though the latter is not used in the excerpt.
#
# The core logic uses the `find` command to look for top-level directories whose names are in ALL CAPS (matching the regular expression `^[A-Z][A-Z0-9_-]*$`). For each such directory, it searches recursively for `.ipynb` files, excluding any within .ipynb_checkpoints subdirectories. All found notebook paths are collected into the `notebook_paths` array.
#
# If no notebooks are found, the script writes an empty output file and prints a message indicating that no notebooks were found under the specified directory structure. If notebooks are found, their paths are written to the output file, one per line. The script also creates a temporary file for further processing, though the excerpt ends before showing how this temporary file is used.
#
# Overall, this script automates the process of cataloging Jupyter notebooks in a workspace that uses a convention of ALL-CAPS directory names for top-level folders, making it easier to manage or process these notebooks in subsequent steps.
