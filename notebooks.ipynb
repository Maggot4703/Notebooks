# %% [markdown]
# ---
# ---
# ---
#
# # notebooks.ipynb

# %% [markdown]
# ---
# ---
#
# # NOTEBOOKS

# %% [markdown]
# ---
#
# ## /home/me/Notebooks

# %%
# !cd /home/me/Notebooks
# !ls *.ipynb
# Out:
# ai.ipynb    calibre.ipynb      crew.ipynb	 notebooks.ipynb
# bash.ipynb  card-cutter.ipynb  jupyterlab.ipynb  python.ipynb

# %% [markdown]
# ---
#
# ## /home/me/Notebooks/AI

# %%
# !ls /home/me/Notebooks/AI/
# Out:
# agents	 ai.ipynb  markdown	   README.md  startup.txt  uv.lock
# ai.html  main.py   pyproject.toml  skills     T5-books

# %% [markdown]
# ---
#
# ## /home/me/Notebooks/BASH

# %%
# !ls /home/me/Notebooks/BASH/
# Out:
# BASH.code-workspace  bash.ipynb    main.py	 pyproject.toml
# bash_commands.txt    command-help  Pipfile	 README.md
# bash.html	     commands	   Pipfile.lock  startup.txt

# %% [markdown]
# ---
#
# ## /home/me/Notebooks/CALIBRE

# %%
# !ls /home/me/Notebooks/CALIBRE
# Out:
# calibre.html	  main.py	   Pipfile.lock    startup.txt
# calibre.ipynb	  man-calibre.txt  pyproject.toml  uv.lock
# help-calibre.txt  Pipfile	   README.md

# %% [markdown]
# ---
#
# ## /home/me/Notebooks/CARDCUTTER

# %%
# !ls /home/me/Notebooks/CARDCUTTER
# Out:
# CardCutter	  card-cutter.ipynb  pyproject.toml  startup.txt
# card-cutter.html  main.py	     README.md

# %% [markdown]
# ---
#
# ## /home/me/Notebooks/CREW

# %%
# !ls /home/me/Notebooks/CREW
# Out:
# config.json   CREW.code-workspace  crew.html   pyproject.toml
# Crew	      crew_data.db	   crew.ipynb  README.md
# crew_app.log  crew_gui.log	   main.py     startup.txt

# %% [markdown]
# ---
#
# ## /home/me/Notebooks/JUPYTERLAB

# %%
# !ls /home/me/Notebooks/JUPYTERLAB
# Out:
# jupterlab_files		   jupyterlab.html   main.py	     README.md
# JUPYTERLAB.code-workspace  jupyterlab.ipynb  pyproject.toml  startup.txt

# %% [markdown]
# ---
#
# ## /home/me/Notebooks/PYTHON

# %%
# !ls /home/me/Notebooks/PYTHON
# Out:
# main.py  PWD		 PYTHON.code-workspace	python.ipynb  startup.txt
# Pipfile  pyproject.toml  python.html		README.md

# %% [markdown]
# ---
#
# ## /home/me/Notebooks/TRAVELLERMAP

# %%
# !ls /home/me/Notebooks/TRAVELLERMAP
# Out:
# check_travellermap_api_version.py  crew_gui.log  scripts
# check_travellermap_data_schema.py  data		 startup.txt
# config.json			   docs		 TRAVELLERMAP.code-workspace
# count_military_bases.py		   notebooks	 vland.html
# crew_app.log			   output
# crew_data.db			   __pycache__
